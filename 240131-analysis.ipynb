# %%
import pandas as pd
import numpy as np 
import time
from timeit import default_timer as timer
from datetime import timedelta
import urllib
from datetime import datetime
import matplotlib.pyplot as plt 
import seaborn as sns

import requests
requests.packages.urllib3.disable_warnings()

pd.options.mode.chained_assignment = None
pd.options.display.max_columns = None

access_token='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' 
headers = {'Authorization':"Token "+access_token}

# %% [markdown]
# ### Define the functions : input - output
# created_at         : name of the repository - creation date of the repository \
# stargazers_count   : name of the repository - number of stars given to the repository \
# watchers_count     : name of the repository - number of watchers of the repository \
# open_issue_count   : name of the repository - # of open issues (not including pull requests) the repository \
# closed_issue_count : name of the repository - # of closed issues (not including pull requests) the repository \
# open_pr_count      : name of the repository - # of open pull requests (not including other issues that are not pull requests) the repository \
# open_pr_count_v2   : name of the repository - # of open pull requests (not including other issues that are not pull requests) the repository - added on 10.01.2024 \
# closed_pr_count    : name of the repository - # of closed pull requests (not including other issues that are not pull requests) the repository \
# closed_pr_count_v2 : name of the repository - # of closed pull requests (not including other issues that are not pull requests) the repository - added on 10.01.2024 \
# commit_count       : name of the repository - # of commits made in the repository \
# release_count      : name of the repository - # of releases made in the repository \
# issue_info         : name of the repository - issue data as df \
# pullRequest_info   : name of the repository - pull request data as df \
# label_info         : name of the repository - label data of the labels that are used in the repository as df \
# release_info       : name of the repository - release data as df \
# issue_release_tag  : release_info,name of the repository,created_at - tag of the current release of the repository when the issue was created \
# issue_release_date : release_info,name of the repository,created_at - date of the current release of the repository when the issue was created \
# issue_release_graph: issue_info,name of the repository - graph of the number of issues created through the releases of the repository

# %%
def created_at(repository):
    k = 0
    while k < 100:
        try:
            url = f"https://api.github.com/repos/{repository}"
            result = requests.get(url,headers=headers,verify=False).json()
            created_at = result['created_at']
            k = 100
        except:
            time.sleep(90)
            continue 
    return created_at

def stargazers_count(repository):
    k = 0
    while k < 100:
        try:
            url = f"https://api.github.com/repos/{repository}"
            result = requests.get(url,headers=headers,verify=False).json()
            stargazers_count = result['stargazers_count']
            k = 100
        except:
            time.sleep(90)
            continue 
    return stargazers_count

def watchers_count(repository):
    k = 0
    while k < 100:
        try:
            url = f"https://api.github.com/repos/{repository}"
            result = requests.get(url,headers=headers,verify=False).json()
            subscribers_count = result['subscribers_count']
            k = 100
        except:
            time.sleep(90)
            continue 
    return subscribers_count

def open_issue_count(repository):
    k = 0
    while k < 100:
        try:
            url = f"https://api.github.com/search/issues?q=repo:{repository}+type:issue+state:open"
            result = requests.get(url,headers=headers,verify=False).json()
            open_issue_count = result['total_count']
            k = 100
        except:
            time.sleep(90)
            continue 
    return open_issue_count

def closed_issue_count(repository):
    k = 0
    while k < 100:
        try:
            url = f"https://api.github.com/search/issues?q=repo:{repository}+type:issue+state:closed"
            result = requests.get(url,headers=headers,verify=False).json()
            closed_issue_count = result['total_count']
            k = 100
        except:
            time.sleep(90)
            continue 
    return closed_issue_count

def open_pr_count(repository):
    k = 0
    while k < 100:
        try:
            url = f"https://api.github.com/search/issues?q=repo:{repository}+type:pull-request+state:open"
            result = requests.get(url,headers=headers,verify=False).json()
            open_pr_count = result['total_count']
            k = 100
        except:
            time.sleep(90)
            continue 
    return open_pr_count

def open_pr_count_v2(repository):
    k = 0
    while k < 100:
        try:
            url = f"https://api.github.com/search/issues?q=repo:{repository}+is:pr+state:open"
            result = requests.get(url,headers=headers,verify=False).json()
            open_pr_count = result['total_count']
            k = 100
        except:
            time.sleep(90)
            continue 
    return open_pr_count

def closed_pr_count(repository):
    k = 0
    while k < 100:
        try:
            url = f"https://api.github.com/search/issues?q=repo:{repository}+type:pull-request+state:closed"
            result = requests.get(url,headers=headers,verify=False).json()
            closed_pr_count = result['total_count']
            k = 100
        except:
            time.sleep(90)
            continue 
    return closed_pr_count  

def closed_pr_count_v2(repository):
    k = 0
    while k < 100:
        try:
            url = f"https://api.github.com/search/issues?q=repo:{repository}+is:pr+state:closed"
            result = requests.get(url,headers=headers,verify=False).json()
            closed_pr_count = result['total_count']
            k = 100
        except:
            time.sleep(90)
            continue 
    return closed_pr_count 

def commit_count(repository):
    url = f'https://api.github.com/repos/{repository}/commits'
    headers = {'Authorization':"Token "+access_token, 'Accept': 'application/json', 'Content-Type': 'application/json'}
    params = {'per_page': 1}
    k = 0
    while k < 100:
        try:
            resp = requests.request('GET', url, params=params, headers=headers, verify=False)
            commit_count = len(resp.json())
            last_page = resp.links.get('last')
            # if there are no more pages, the count must be 0 or 1
            k = 1000
            if last_page:
                # extract the query string from the last page url
                qs = urllib.parse.urlparse(last_page['url']).query
                # extract the page number from the query string
                commit_count = int(dict(urllib.parse.parse_qsl(qs))['page'])
        except:
            time.sleep(90)
            continue
    return commit_count

def release_count(repository):
    url = f'https://api.github.com/repos/{repository}/releases'
    headers = {'Authorization':"Token "+access_token, 'Accept': 'application/json', 'Content-Type': 'application/json'}
    params = {'per_page': 1}
    k = 0
    while k < 100:
        try:
            resp = requests.request('GET', url, params=params, headers=headers, verify=False)
            release_count = len(resp.json())
            last_page = resp.links.get('last')
            # if there are no more pages, the count must be 0 or 1
            k = 1000
            if last_page:
                # extract the query string from the last page url
                qs = urllib.parse.urlparse(last_page['url']).query
                # extract the page number from the query string
                release_count = int(dict(urllib.parse.parse_qsl(qs))['page'])
        except:
            time.sleep(90)
            continue
    return release_count

def release_info(repository):
    page_num = 1
    releases = []
    while page_num < 33:
        try:
            url = f"https://api.github.com/repos/{repository}/releases?page={page_num}"
            release = requests.get(url,headers=headers,verify=False).json()
            result = release
            if result == []:
                page_num = 100
            else:  
                releases.append(release)
                page_num = page_num + 1
        except:
            time.sleep(120)
            continue
    url=[]
    assets_url=[]
    upload_url=[]
    html_url=[]
    release_id=[]
    author=[]
    node_id=[]
    tag_name=[]
    target_commitish=[]
    name=[]
    draft=[]
    prerelease=[]
    created_at=[]
    published_at=[]
    assets=[]
    tarball_url=[]
    zipball_url=[]
    body=[]
    for page in releases:
        for release in page:
            try:
                url.append(release['url'])
                assets_url.append(release['assets_url'])
                upload_url.append(release['upload_url'])
                html_url.append(release['html_url'])
                release_id.append(release['id'])
                author.append(release['author'])
                node_id.append(release['node_id'])
                tag_name.append(release['tag_name'])
                target_commitish.append(release['target_commitish'])
                name.append(release['name'])
                draft.append(release['draft'])
                prerelease.append(release['prerelease'])
                created_at.append(release['created_at'])
                published_at.append(release['published_at'])
                assets.append(release['assets'])
                tarball_url.append(release['tarball_url'])
                zipball_url.append(release['zipball_url'])
                body.append(release['body'])
            except:
                pass
    release_data=pd.DataFrame()
    release_data['url']=url
    release_data['assets_url']=assets_url
    release_data['upload_url']=upload_url
    release_data['html_url']=html_url
    release_data['release_id']=release_id
    release_data['author']=author
    release_data['node_id']=node_id
    release_data['tag_name']=tag_name
    release_data['target_commitish']=target_commitish
    release_data['name']=name
    release_data['draft']=draft
    release_data['prerelease']=prerelease
    release_data['created_at']=created_at
    release_data['published_at']=published_at
    release_data['assets']=assets
    release_data['tarball_url']=tarball_url
    release_data['zipball_url']=zipball_url
    release_data['body']=body
    release_data['repository_name']=repository
    release_data=release_data.reset_index().drop(columns='index')
    return release_data

def issue_release_date(releases,repository,created_at):
    release_df = releases[releases['repository_name'] == repository]
    release_df.sort_values(by='published_at', ascending = False, inplace = True)
    release_df = release_df.reset_index(drop=True)
    r = 0
    release_date = '2010-01-01T00:00:00Z'
    while r < release_df.shape[0]:
        if created_at < release_df.loc[r,'published_at']:
            r += 1
        else:
            release_date = release_df.loc[r,'published_at']
            break
    return release_date

def issue_release_tag(releases,repository,created_at):
    release_df = releases[(releases['repository_name'] == repository)]
    release_df.sort_values(by=['published_at'], ascending = False, inplace = True)
    release_df = release_df.reset_index(drop=True)
    r = 0
    tag = 'prerelease'
    while r < release_df.shape[0]:
        if created_at < release_df.loc[r,'published_at']:
            r += 1
        else:
            tag = release_df.loc[r,'tag_name2']
            break
    return tag

# %% [markdown]
# ### Read the initial list of repositories and get statistics

# %%
initial_repolist = pd.read_csv("/Users/isdeniz/Documents/github/231008-repolist.csv")
initial_repolist.shape[0]
# Out:
# 171

# %%
# i = 0
# while i < initial_repolist.shape[0]:
#     repository = initial_repolist.loc[i,'repository_name']
#     initial_repolist.loc[i,'created_at'] = created_at(repository) 
#     initial_repolist.loc[i,'stargazers_count'] = stargazers_count(repository) 
#     initial_repolist.loc[i,'watchers_count'] = watchers_count(repository) 
#     initial_repolist.loc[i,'open_issue_count'] = open_issue_count(repository) 
#     initial_repolist.loc[i,'closed_issue_count'] = closed_issue_count(repository) 
#     initial_repolist.loc[i,'issue_count'] = initial_repolist.loc[i,'open_issue_count'] + initial_repolist.loc[i,'closed_issue_count'] 
#     initial_repolist.loc[i,'open_pr_count'] = open_pr_count(repository) 
#     initial_repolist.loc[i,'closed_pr_count'] = closed_pr_count(repository) 
#     initial_repolist.loc[i,'pr_count'] = initial_repolist.loc[i,'open_pr_count'] + initial_repolist.loc[i,'closed_pr_count'] 
#     initial_repolist.loc[i,'commit_count'] = commit_count(repository) 
#     initial_repolist.loc[i,'release_count'] =  release_count(repository)
#     print('repository',i,repository,'is ready')
#     i = i + 1
#     # 48 min - run on 08.10.2023 for 171 repositories

# %%
# initial_repolist.to_pickle("231008-initial-repolist-count-info.pkl")

# %%
initial_repolist = pd.read_pickle('/Users/isdeniz/Documents/github/231008-initial-repolist-count-info.pkl')

# %%
print('total_issue_count: ',initial_repolist['issue_count'].sum())
print('total_open_issue_count: ',initial_repolist['open_issue_count'].sum())
print('total_closed_issue_count: ',initial_repolist['closed_issue_count'].sum())
print('total_pr_count: ',initial_repolist['pr_count'].sum())
print('total_open_pr_count: ',initial_repolist['open_pr_count'].sum())
print('total_closed_pr_count: ',initial_repolist['closed_pr_count'].sum())
print('total_commit_count: ',initial_repolist['commit_count'].sum())
print('total_release_count: ',initial_repolist['release_count'].sum())
# Out:
# total_issue_count:  480134.0
# total_open_issue_count:  66878.0
# total_closed_issue_count:  413256.0
# total_pr_count:  460956.0
# total_open_pr_count:  12176.0
# total_closed_pr_count:  448780.0
# total_commit_count:  2227380.0
# total_release_count:  8249.0

# %%
initial_repolist[initial_repolist['repository_name'] == 'dromara/hutool']
# Out:
#    repository_name            created_at  stargazers_count  watchers_count  \
# 31  dromara/hutool  2014-04-13T07:23:51Z           27167.0           607.0
#
#     open_issue_count  closed_issue_count  issue_count  open_pr_count  \
# 31               4.0              2457.0       2461.0            1.0
#
#     closed_pr_count  pr_count  commit_count  release_count
# 31            798.0     799.0        4826.0          135.0

# %% [markdown]
# ### Selecting the repositories satisfying thresholds in terms of the number of issues, pull requests, commits, and releases

# %%
repolist = initial_repolist[(initial_repolist.issue_count >= 1000) & (initial_repolist.pr_count >= 1000) & (initial_repolist.commit_count >= 1000) & (initial_repolist.release_count >= 50)]
repolist = repolist.reset_index(drop=True)
repolist.shape[0]
# Out:
# 32

# %%
repolist
# Out:
#                      repository_name            created_at  stargazers_count  \
# 0              facebook/react-native  2015-01-09T18:10:16Z          112304.0
# 1        spring-projects/spring-boot  2012-10-19T15:02:57Z           69590.0
# 2              elastic/elasticsearch  2010-02-08T13:20:56Z           65337.0
# 3   spring-projects/spring-framework  2010-12-08T04:04:45Z           53315.0
# 4                   ReactiveX/RxJava  2013-01-08T20:11:48Z           47252.0
# 5                       apache/dubbo  2012-06-19T07:56:02Z           39423.0
# 6                    dbeaver/dbeaver  2015-10-21T08:26:28Z           34008.0
# 7                      halo-dev/halo  2018-03-21T12:56:52Z           28903.0
# 8                SeleniumHQ/selenium  2013-01-14T21:40:56Z           27947.0
# 9                      alibaba/nacos  2018-06-15T06:49:27Z           27620.0
# 10               TeamNewPipe/NewPipe  2015-09-03T23:39:26Z           25486.0
# 11                 apache/skywalking  2015-11-07T03:30:36Z           22466.0
# 12                  bazelbuild/bazel  2014-06-12T16:00:38Z           21444.0
# 13                  Anuken/Mindustry  2017-04-30T01:24:29Z           19237.0
# 14             apache/shardingsphere  2016-01-18T12:49:26Z           18838.0
# 15    OpenAPITools/openapi-generator  2018-05-12T09:57:56Z           17783.0
# 16                 openzipkin/zipkin  2012-06-06T18:26:16Z           16441.0
# 17           thingsboard/thingsboard  2016-12-01T09:33:30Z           14446.0
# 18                   mockito/mockito  2012-10-13T20:27:12Z           14224.0
# 19                  elastic/logstash  2010-11-18T01:31:50Z           13655.0
# 20                     apache/pulsar  2016-06-28T07:00:03Z           13200.0
# 21          GoogleContainerTools/jib  2018-01-22T18:30:43Z           13016.0
# 22             pinpoint-apm/pinpoint  2014-10-20T09:27:22Z           13006.0
# 23                      apache/druid  2012-10-23T19:08:07Z           12879.0
# 24                   questdb/questdb  2014-04-28T23:29:15Z           12845.0
# 25                 quarkusio/quarkus  2018-07-06T00:44:20Z           12349.0
# 26     codecentric/spring-boot-admin  2014-07-25T11:39:13Z           11914.0
# 27                       neo4j/neo4j  2012-11-12T08:46:15Z           11849.0
# 28                       redis/jedis  2010-06-11T13:04:43Z           11336.0
# 29                   zaproxy/zaproxy  2015-06-03T16:55:01Z           11302.0
# 30                    grpc/grpc-java  2014-12-08T19:00:00Z           10829.0
# 31                 Netflix/conductor  2016-12-07T22:48:42Z           10883.0
#
#     watchers_count  open_issue_count  closed_issue_count  issue_count  \
# 0           3631.0            1583.0             23680.0      25263.0
# 1           3367.0             631.0             30825.0      31456.0
# 2           2680.0            3935.0             29241.0      33176.0
# 3           3370.0             818.0             23309.0      24127.0
# 4           2241.0              17.0              3119.0       3136.0
# 5           3071.0             942.0              5546.0       6488.0
# 6            514.0            1778.0             13556.0      15334.0
# 7            473.0             298.0              2515.0       2813.0
# 8           1320.0             189.0              9301.0       9490.0
# 9            912.0             244.0              7324.0       7568.0
# 10           590.0            1191.0              7044.0       8235.0
# 11           847.0              47.0              4891.0       4938.0
# 12           608.0            1674.0             10226.0      11900.0
# 13           550.0               0.0              3997.0       3997.0
# 14          1021.0            1141.0              9133.0      10274.0
# 15           212.0            3819.0              3309.0       7128.0
# 16           696.0             205.0              1104.0       1309.0
# 17           546.0            1367.0              4050.0       5417.0
# 18           423.0             349.0              1214.0       1563.0
# 19           828.0            1890.0              4623.0       6513.0
# 20           406.0             919.0              5533.0       6452.0
# 21           329.0             140.0              1431.0       1571.0
# 22           746.0             362.0              3627.0       3989.0
# 23           600.0            1041.0              3718.0       4759.0
# 24           131.0             375.0              1011.0       1386.0
# 25           272.0            2177.0             12572.0      14749.0
# 26           662.0              22.0              1566.0       1588.0
# 27           519.0             308.0              3187.0       3495.0
# 28           689.0             132.0              1598.0       1730.0
# 29           397.0             704.0              4028.0       4732.0
# 30           523.0             441.0              2816.0       3257.0
# 31           506.0             126.0              1417.0       1543.0
#
#     open_pr_count  closed_pr_count  pr_count  commit_count  release_count
# 0           280.0          13956.0   14236.0       29273.0          276.0
# 1            23.0           5850.0    5873.0       45478.0          249.0
# 2           555.0          66416.0   66971.0       72450.0          123.0
# 3            58.0           4351.0    4409.0       28190.0          268.0
# 4             0.0           3799.0    3799.0        6051.0          233.0
# 5            69.0           6459.0    6528.0        7125.0           90.0
# 6            35.0           4522.0    4557.0       24773.0          184.0
# 7             8.0           1662.0    1670.0        4514.0          136.0
# 8            55.0           3194.0    3249.0       30472.0           86.0
# 9            28.0           3487.0    3515.0        4790.0           58.0
# 10           36.0           1953.0    1989.0       10972.0          126.0
# 11            7.0           4846.0    4853.0        7767.0           57.0
# 12          177.0           6970.0    7147.0       37467.0          228.0
# 13          167.0           4817.0    4984.0       16947.0          160.0
# 14           39.0          18152.0   18191.0       40547.0           54.0
# 15          409.0           9111.0    9520.0       19207.0           58.0
# 16           21.0           2192.0    2213.0        2745.0           72.0
# 17           78.0           3856.0    3934.0       15529.0           56.0
# 18           11.0           1553.0    1564.0        5984.0          204.0
# 19          193.0           8596.0    8789.0       10504.0          123.0
# 20          293.0          14080.0   14373.0       11992.0           71.0
# 21           29.0           2518.0    2547.0        2320.0          151.0
# 22           51.0           6304.0    6355.0       13323.0           55.0
# 23          267.0          10038.0   10305.0       13263.0           55.0
# 24           20.0           2304.0    2324.0        4335.0           72.0
# 25          166.0          19777.0   19943.0       41067.0          261.0
# 26            2.0           1209.0    1211.0        2517.0          111.0
# 27            1.0           9652.0    9653.0       77553.0           72.0
# 28           57.0           1643.0    1700.0        2283.0           89.0
# 29           25.0           3306.0    3331.0        9267.0          337.0
# 30           54.0           7265.0    7319.0        6038.0          149.0
# 31           16.0           1643.0    1659.0        3290.0          318.0

# %%
print('total_issue_count_of_selected_repos: ',repolist['issue_count'].sum())
print('total_open_issue_count_of_selected_repos: ',repolist['open_issue_count'].sum())
print('total_closed_issue_count_of_selected_repos: ',repolist['closed_issue_count'].sum())
print('total_pr_count_of_selected_repos: ',repolist['pr_count'].sum())
print('total_open_pr_count_of_selected_repos: ',repolist['open_pr_count'].sum())
print('total_closed_pr_count_of_selected_repos: ',repolist['closed_pr_count'].sum())
print('total_commit_count_of_selected_repos: ',repolist['commit_count'].sum())
print('total_release_count_of_selected_repos: ',repolist['release_count'].sum())
# Out:
# total_issue_count_of_selected_repos:  269376.0
# total_open_issue_count_of_selected_repos:  28865.0
# total_closed_issue_count_of_selected_repos:  240511.0
# total_pr_count_of_selected_repos:  258711.0
# total_open_pr_count_of_selected_repos:  3230.0
# total_closed_pr_count_of_selected_repos:  255481.0
# total_commit_count_of_selected_repos:  608033.0
# total_release_count_of_selected_repos:  4582.0

# %% [markdown]
# ### Retrieve releases of the selected repositories

# %%
# i = 0
# releases = pd.DataFrame()
# while i < repolist.shape[0]:
#     start = timer()
#     new_release = release_info(repolist.loc[i,'repository_name'])
#     releases = pd.concat([releases, new_release], ignore_index=True)
#     end = timer()
#     print('repository',i,repolist.loc[i,'repository_name'],'is ready','current # of releases: ',releases.shape[0],'duration: ',(timedelta(seconds=end-start))/60)
#     i = i + 1

# %%
# releases.to_pickle("231008-releases.pkl")

# %%
releases = pd.read_pickle('/Users/isdeniz/Documents/github/231008-releases.pkl')
print(releases.shape[0])
# Out:
# 4584

# %%
j = 0
while j < releases.shape[0]:
    releases.loc[j,'published_at_timestamp'] = datetime.strptime(releases.loc[j,'published_at'], '%Y-%m-%dT%H:%M:%SZ')
    j = j + 1

# %%
print('prerelease == True: ',releases[releases['prerelease'] == True].shape[0],'prerelease == False: ',releases[releases['prerelease'] == False].shape[0])
# Out:
# prerelease == True:  1045 prerelease == False:  3539

# %%
print('draft == True: ',releases[releases['draft'] == True].shape[0],'draft == False: ',releases[releases['draft'] == False].shape[0])
# Out:
# draft == True:  0 draft == False:  4584

# %%
stable_releases = releases.copy(deep=True)
stable_releases = stable_releases.drop(stable_releases[stable_releases['prerelease'] == True].index)
stable_releases = stable_releases.reset_index(drop=True)
stable_releases.shape[0]
# Out:
# 3539

# %%
df1 = releases.groupby(['repository_name'])['tag_name'].count()

# %%
df2 = stable_releases.groupby(['repository_name'])['tag_name'].count()

# %%
# c = ['tag_name','name','prerelease','published_at','repository_name']
# releases.to_csv('231008-releases-tag.csv', columns = c,index=False)

# %% [markdown]
# Manual Correction for
# repository: questdb/questdb release tag_name: v2.0.1 (questdb-2.0-2.1) and 2.0.1 (questdb-2.0.1)
# and
# epository: questdb/questdb release tag_name: v2.0.1 (questdb-2.0-2.0)

# %%
stable_releases[(stable_releases['repository_name'] == 'questdb/questdb') & (stable_releases['tag_name'] == 'v2.0.1')]
# Out:
#                                                     url  \
# 2744  https://api.github.com/repos/questdb/questdb/r...
#
#                                              assets_url  \
# 2744  https://api.github.com/repos/questdb/questdb/r...
#
#                                              upload_url  \
# 2744  https://uploads.github.com/repos/questdb/quest...
#
#                                                html_url  release_id  \
# 2744  https://github.com/questdb/questdb/releases/ta...     8625988
#
#                                                  author  \
# 2744  {'login': 'bluestreak01', 'id': 7276403, 'node...
#
#                        node_id tag_name target_commitish           name  \
# 2744  MDc6UmVsZWFzZTg2MjU5ODg=   v2.0.1           master  QuestDB 2.0.1
#
#       draft  prerelease            created_at          published_at assets  \
# 2744  False       False  2017-11-22T20:01:43Z  2017-11-22T20:06:56Z     []
#
#                                             tarball_url  \
# 2744  https://api.github.com/repos/questdb/questdb/t...
#
#                                             zipball_url  \
# 2744  https://api.github.com/repos/questdb/questdb/z...
#
#                                                    body  repository_name  \
# 2744  Release notes\r\n\r\n- BUGFIX: microsecond tim...  questdb/questdb
#
#      published_at_timestamp
# 2744    2017-11-22 20:06:56

# %%
stable_releases[(stable_releases['repository_name'] == 'questdb/questdb') & (stable_releases['tag_name'] == 'v2.0.0')]
# Out:
#                                                     url  \
# 2745  https://api.github.com/repos/questdb/questdb/r...
#
#                                              assets_url  \
# 2745  https://api.github.com/repos/questdb/questdb/r...
#
#                                              upload_url  \
# 2745  https://uploads.github.com/repos/questdb/quest...
#
#                                                html_url  release_id  \
# 2745  https://github.com/questdb/questdb/releases/ta...     8579821
#
#                                                  author  \
# 2745  {'login': 'bluestreak01', 'id': 7276403, 'node...
#
#                        node_id tag_name target_commitish           name  \
# 2745  MDc6UmVsZWFzZTg1Nzk4MjE=   v2.0.0           master  QuestDB 2.0.0
#
#       draft  prerelease            created_at          published_at assets  \
# 2745  False       False  2017-11-19T22:33:46Z  2017-11-19T23:08:56Z     []
#
#                                             tarball_url  \
# 2745  https://api.github.com/repos/questdb/questdb/t...
#
#                                             zipball_url  \
# 2745  https://api.github.com/repos/questdb/questdb/z...
#
#                                                    body  repository_name  \
# 2745  This release introduces new storage system, CA...  questdb/questdb
#
#      published_at_timestamp
# 2745    2017-11-19 23:08:56

# %%
stable_releases[(stable_releases['repository_name'] == 'questdb/questdb') & (stable_releases['tag_name'] == 'v1.0.1')]
# Out:
#                                                     url  \
# 2748  https://api.github.com/repos/questdb/questdb/r...
#
#                                              assets_url  \
# 2748  https://api.github.com/repos/questdb/questdb/r...
#
#                                              upload_url  \
# 2748  https://uploads.github.com/repos/questdb/quest...
#
#                                                html_url  release_id  \
# 2748  https://github.com/questdb/questdb/releases/ta...     4435957
#
#                                                  author  \
# 2748  {'login': 'bluestreak01', 'id': 7276403, 'node...
#
#                        node_id tag_name target_commitish           name  \
# 2748  MDc6UmVsZWFzZTQ0MzU5NTc=   v1.0.1           master  QuestDB 1.0.1
#
#       draft  prerelease            created_at          published_at assets  \
# 2748  False       False  2016-10-20T00:46:52Z  2016-10-20T00:50:28Z     []
#
#                                             tarball_url  \
# 2748  https://api.github.com/repos/questdb/questdb/t...
#
#                                             zipball_url  \
# 2748  https://api.github.com/repos/questdb/questdb/z...
#
#                                                    body  repository_name  \
# 2748  # Bugfixes\n- fixed windows distribution (ques...  questdb/questdb
#
#      published_at_timestamp
# 2748    2016-10-20 00:50:28

# %%
stable_releases[(stable_releases['repository_name'] == 'questdb/questdb') & (stable_releases['tag_name'] == 'v1.0.3')]
# Out:
#                                                     url  \
# 2747  https://api.github.com/repos/questdb/questdb/r...
#
#                                              assets_url  \
# 2747  https://api.github.com/repos/questdb/questdb/r...
#
#                                              upload_url  \
# 2747  https://uploads.github.com/repos/questdb/quest...
#
#                                                html_url  release_id  \
# 2747  https://github.com/questdb/questdb/releases/ta...     4489105
#
#                                                  author  \
# 2747  {'login': 'bluestreak01', 'id': 7276403, 'node...
#
#                        node_id tag_name target_commitish           name  \
# 2747  MDc6UmVsZWFzZTQ0ODkxMDU=   v1.0.3           master  QuestDB 1.0.3
#
#       draft  prerelease            created_at          published_at assets  \
# 2747  False       False  2017-01-01T15:19:33Z  2017-01-01T21:45:13Z     []
#
#                                             tarball_url  \
# 2747  https://api.github.com/repos/questdb/questdb/t...
#
#                                             zipball_url  \
# 2747  https://api.github.com/repos/questdb/questdb/z...
#
#                                            body  repository_name  \
# 2747  Bugfix release, stability improvements.\n  questdb/questdb
#
#      published_at_timestamp
# 2747    2017-01-01 21:45:13

# %%
def func_tag(x):
    if x.startswith("v"):
        return x[1:]
    elif x.startswith("druid-"):
        return x[6:]
    else:
        return x

# %%
stable_releases['tag_name2'] = stable_releases['tag_name'].apply(func_tag)

# %%
stable_releases.loc[2744,'tag_name2'] = '2.0-2.1'

# %%
stable_releases.loc[2745,'tag_name2'] = '2.0-2.0'

# %%
stable_releases.loc[2748,'tag_name2'] = '1.0-2.1'

# %%
stable_releases.loc[2747,'tag_name2'] = '1.0-2.3'

# %%
stable_releases['published_at_timestamp'] = pd.to_datetime(stable_releases['published_at_timestamp'])

# %%
stable_releases = stable_releases.sort_values('published_at_timestamp')
stable_releases = stable_releases.reset_index(drop=True)

# %% [markdown]
# Excluding the stable releases which returned error in Designite

# %%
stable_releases = stable_releases.drop(stable_releases[(stable_releases['repository_name'] == 'ReactiveX/RxJava') & (stable_releases['tag_name2'] == '3.0.0')].index)
stable_releases = stable_releases.reset_index(drop=True)
stable_releases = stable_releases.drop(stable_releases[(stable_releases['repository_name'] == 'ReactiveX/RxJava') & (stable_releases['tag_name2'] == '3.0.0-RC7')].index)
stable_releases = stable_releases.reset_index(drop=True)
stable_releases = stable_releases.drop(stable_releases[(stable_releases['repository_name'] == 'ReactiveX/RxJava') & (stable_releases['tag_name2'] == '3.0.0-RC8')].index)
stable_releases = stable_releases.reset_index(drop=True)
stable_releases = stable_releases.drop(stable_releases[(stable_releases['repository_name'] == 'ReactiveX/RxJava') & (stable_releases['tag_name2'] == '3.0.0-RC9')].index)
stable_releases = stable_releases.reset_index(drop=True)
stable_releases = stable_releases.drop(stable_releases[(stable_releases['repository_name'] == 'ReactiveX/RxJava') & (stable_releases['tag_name2'] == '3.0.1')].index)
stable_releases = stable_releases.reset_index(drop=True)
stable_releases = stable_releases.drop(stable_releases[(stable_releases['repository_name'] == 'ReactiveX/RxJava') & (stable_releases['tag_name2'] == '3.0.2')].index)
stable_releases = stable_releases.reset_index(drop=True)
stable_releases = stable_releases.drop(stable_releases[(stable_releases['repository_name'] == 'ReactiveX/RxJava') & (stable_releases['tag_name2'] == '3.0.3')].index)
stable_releases = stable_releases.reset_index(drop=True)
stable_releases = stable_releases.drop(stable_releases[(stable_releases['repository_name'] == 'ReactiveX/RxJava') & (stable_releases['tag_name2'] == '3.0.4')].index)
stable_releases = stable_releases.reset_index(drop=True)
stable_releases = stable_releases.drop(stable_releases[(stable_releases['repository_name'] == 'ReactiveX/RxJava') & (stable_releases['tag_name2'] == '3.0.5')].index)
stable_releases = stable_releases.reset_index(drop=True)
stable_releases = stable_releases.drop(stable_releases[(stable_releases['repository_name'] == 'ReactiveX/RxJava') & (stable_releases['tag_name2'] == '3.0.6')].index)
stable_releases = stable_releases.reset_index(drop=True)
stable_releases = stable_releases.drop(stable_releases[(stable_releases['repository_name'] == 'ReactiveX/RxJava') & (stable_releases['tag_name2'] == '3.0.7')].index)
stable_releases = stable_releases.reset_index(drop=True)
stable_releases = stable_releases.drop(stable_releases[(stable_releases['repository_name'] == 'ReactiveX/RxJava') & (stable_releases['tag_name2'] == '3.0.8')].index)
stable_releases = stable_releases.reset_index(drop=True)
stable_releases = stable_releases.drop(stable_releases[(stable_releases['repository_name'] == 'ReactiveX/RxJava') & (stable_releases['tag_name2'] == '3.0.9')].index)
stable_releases = stable_releases.reset_index(drop=True)
stable_releases = stable_releases.drop(stable_releases[(stable_releases['repository_name'] == 'ReactiveX/RxJava') & (stable_releases['tag_name2'] == '3.0.10')].index)
stable_releases = stable_releases.reset_index(drop=True)
stable_releases = stable_releases.drop(stable_releases[(stable_releases['repository_name'] == 'ReactiveX/RxJava') & (stable_releases['tag_name2'] == '3.0.11')].index)
stable_releases = stable_releases.reset_index(drop=True)
stable_releases = stable_releases.drop(stable_releases[(stable_releases['repository_name'] == 'ReactiveX/RxJava') & (stable_releases['tag_name2'] == '3.0.12')].index)
stable_releases = stable_releases.reset_index(drop=True)
stable_releases = stable_releases.drop(stable_releases[(stable_releases['repository_name'] == 'ReactiveX/RxJava') & (stable_releases['tag_name2'] == '3.0.13')].index)
stable_releases = stable_releases.reset_index(drop=True)
stable_releases = stable_releases.drop(stable_releases[(stable_releases['repository_name'] == 'ReactiveX/RxJava') & (stable_releases['tag_name2'] == '3.1.0')].index)
stable_releases = stable_releases.reset_index(drop=True)
stable_releases = stable_releases.drop(stable_releases[(stable_releases['repository_name'] == 'ReactiveX/RxJava') & (stable_releases['tag_name2'] == '3.1.1')].index)
stable_releases = stable_releases.reset_index(drop=True)
stable_releases = stable_releases.drop(stable_releases[(stable_releases['repository_name'] == 'ReactiveX/RxJava') & (stable_releases['tag_name2'] == '3.1.2')].index)
stable_releases = stable_releases.reset_index(drop=True)
stable_releases = stable_releases.drop(stable_releases[(stable_releases['repository_name'] == 'ReactiveX/RxJava') & (stable_releases['tag_name2'] == '3.1.3')].index)
stable_releases = stable_releases.reset_index(drop=True)
stable_releases = stable_releases.drop(stable_releases[(stable_releases['repository_name'] == 'ReactiveX/RxJava') & (stable_releases['tag_name2'] == '3.1.4')].index)
stable_releases = stable_releases.reset_index(drop=True)
stable_releases = stable_releases.drop(stable_releases[(stable_releases['repository_name'] == 'ReactiveX/RxJava') & (stable_releases['tag_name2'] == '3.1.5')].index)
stable_releases = stable_releases.reset_index(drop=True)
stable_releases = stable_releases.drop(stable_releases[(stable_releases['repository_name'] == 'ReactiveX/RxJava') & (stable_releases['tag_name2'] == '3.1.6')].index)
stable_releases = stable_releases.reset_index(drop=True)
stable_releases = stable_releases.drop(stable_releases[(stable_releases['repository_name'] == 'ReactiveX/RxJava') & (stable_releases['tag_name2'] == '3.1.7')].index)
stable_releases = stable_releases.reset_index(drop=True)
stable_releases = stable_releases.drop(stable_releases[(stable_releases['repository_name'] == 'ReactiveX/RxJava') & (stable_releases['tag_name2'] == '3.1.8')].index)
stable_releases = stable_releases.reset_index(drop=True)
stable_releases = stable_releases.drop(stable_releases[(stable_releases['repository_name'] == 'elastic/elasticsearch') & (stable_releases['tag_name2'] == '8.9.2')].index)
stable_releases = stable_releases.reset_index(drop=True)
stable_releases = stable_releases.drop(stable_releases[(stable_releases['repository_name'] == 'elastic/elasticsearch') & (stable_releases['tag_name2'] == '8.10.0')].index)
stable_releases = stable_releases.reset_index(drop=True)
stable_releases = stable_releases.drop(stable_releases[(stable_releases['repository_name'] == 'elastic/elasticsearch') & (stable_releases['tag_name2'] == '8.10.1')].index)
stable_releases = stable_releases.reset_index(drop=True)
stable_releases = stable_releases.drop(stable_releases[(stable_releases['repository_name'] == 'elastic/elasticsearch') & (stable_releases['tag_name2'] == '8.10.2')].index)
stable_releases = stable_releases.reset_index(drop=True)
stable_releases.shape[0]
# Out:
# 3509

# %% [markdown]
# ### Adding the duration of each stable release in days in the 'consecutive_timestamp' column

# %%
stable_releases.sort_values(by=['repository_name', 'published_at_timestamp'], inplace=True)
stable_releases['consecutive_timestamp'] = stable_releases.groupby('repository_name')['published_at_timestamp'].shift(-1)
stable_releases['duration_days'] = (stable_releases['consecutive_timestamp'] - stable_releases['published_at_timestamp']).dt.total_seconds() / 86400
last_rows = stable_releases.groupby('repository_name').tail(1).index
stable_releases.loc[last_rows, 'duration_days'] = (pd.to_datetime('2023-10-08 20:00:00') - stable_releases.loc[last_rows, 'published_at_timestamp']).dt.total_seconds() / 86400
stable_releases = stable_releases.drop(columns=['consecutive_timestamp'])

# %%
bin_width = 1  # Adjust this value as needed
min_value = stable_releases['duration_days'].min()
max_value = stable_releases['duration_days'].max()
num_bins = int(np.ceil((max_value - min_value) / bin_width))

# Plotting histogram
plt.hist(stable_releases['duration_days'], bins=num_bins, edgecolor='black')
plt.xlabel('Release duration in days')
plt.ylabel('Frequency')
plt.title('Histogram of the release duration in days')
plt.grid(True)
plt.show()

# %%
plt.scatter(stable_releases.index,stable_releases['duration_days'])

# %%
stable_releases[stable_releases['duration_days'] <= 1].shape[0]
# Out:
# 797

# %%
stable_releases[stable_releases['duration_days'] >= 0].shape[0]
# Out:
# 3509

# %% [markdown]
# ### Summary of each stable release

# %%
releaseSummary = stable_releases[['tag_name','repository_name','published_at_timestamp','tag_name2','duration_days']]
releaseSummary = releaseSummary.reset_index(drop=True)
releaseSummary.head()
# Out:
#   tag_name   repository_name published_at_timestamp tag_name2  duration_days
# 0      v33  Anuken/Mindustry    2018-03-09 15:14:25        33       4.102558
# 1      v34  Anuken/Mindustry    2018-03-13 17:42:06        34      11.037824
# 2      v35  Anuken/Mindustry    2018-03-24 18:36:34        35       8.017627
# 3      v36  Anuken/Mindustry    2018-04-01 19:01:57        36       1.012917
# 4      v37  Anuken/Mindustry    2018-04-02 19:20:33        37      19.126887

# %%
releaseSummary.shape[0]
# Out:
# 3509

# %% [markdown]
# ### Adding the number of issues created in each stable release

# %%
issues = pd.read_pickle('/Users/isdeniz/Documents/github/231008-issues-time-label.pkl')

# %%
issues.head()
# Out:
#                                                  url  \
# 0  https://api.github.com/repos/facebook/react-na...
# 1  https://api.github.com/repos/facebook/react-na...
# 2  https://api.github.com/repos/facebook/react-na...
# 3  https://api.github.com/repos/facebook/react-na...
# 4  https://api.github.com/repos/facebook/react-na...
#
#                                       repository_url  \
# 0  https://api.github.com/repos/facebook/react-na...
# 1  https://api.github.com/repos/facebook/react-na...
# 2  https://api.github.com/repos/facebook/react-na...
# 3  https://api.github.com/repos/facebook/react-na...
# 4  https://api.github.com/repos/facebook/react-na...
#
#                                           labels_url  \
# 0  ['https://api.github.com/repos/facebook/react-...
# 1  ['https://api.github.com/repos/facebook/react-...
# 2  ['https://api.github.com/repos/facebook/react-...
# 3  ['https://api.github.com/repos/facebook/react-...
# 4  ['https://api.github.com/repos/facebook/react-...
#
#                                         comments_url  \
# 0  https://api.github.com/repos/facebook/react-na...
# 1  https://api.github.com/repos/facebook/react-na...
# 2  https://api.github.com/repos/facebook/react-na...
# 3  https://api.github.com/repos/facebook/react-na...
# 4  https://api.github.com/repos/facebook/react-na...
#
#                                           events_url  \
# 0  https://api.github.com/repos/facebook/react-na...
# 1  https://api.github.com/repos/facebook/react-na...
# 2  https://api.github.com/repos/facebook/react-na...
# 3  https://api.github.com/repos/facebook/react-na...
# 4  https://api.github.com/repos/facebook/react-na...
#
#                                             html_url        id  \
# 0  https://github.com/facebook/react-native/issues/2  55988530
# 1  https://github.com/facebook/react-native/issues/4  56060794
# 2  https://github.com/facebook/react-native/issues/5  56064994
# 3  https://github.com/facebook/react-native/issues/7  56083155
# 4  https://github.com/facebook/react-native/issues/8  56087028
#
#                     node_id  number  \
# 0  MDU6SXNzdWU1NTk4ODUzMA==       2
# 1  MDU6SXNzdWU1NjA2MDc5NA==       4
# 2  MDU6SXNzdWU1NjA2NDk5NA==       5
# 3  MDU6SXNzdWU1NjA4MzE1NQ==       7
# 4  MDU6SXNzdWU1NjA4NzAyOA==       8
#
#                                                title  \
# 0                              `pthread.h` not found
# 1                   Set UIStatusBarStyleLightContent
# 2                             Auto-refresh simulator
# 3  What are the guidelines for exposing native APIs?
# 4                         Support webpack-dev-server
#
#                                                 user  \
# 0  {'login': 'jlongster', 'id': 17031, 'node_id':...
# 1  {'login': 'nick', 'id': 939, 'node_id': 'MDQ6V...
# 2  {'login': 'nick', 'id': 939, 'node_id': 'MDQ6V...
# 3  {'login': 'gaearon', 'id': 810438, 'node_id': ...
# 4  {'login': 'gaearon', 'id': 810438, 'node_id': ...
#
#                                               labels   state  locked assignee  \
# 0  [{'id': 998095527, 'node_id': 'MDU6TGFiZWw5OTg...  closed    True     None
# 1  [{'id': 998095527, 'node_id': 'MDU6TGFiZWw5OTg...  closed    True     None
# 2  [{'id': 998095527, 'node_id': 'MDU6TGFiZWw5OTg...  closed    True     None
# 3  [{'id': 998095527, 'node_id': 'MDU6TGFiZWw5OTg...  closed    True     None
# 4  [{'id': 998095527, 'node_id': 'MDU6TGFiZWw5OTg...  closed    True     None
#
#   assignees milestone  comments            created_at            updated_at  \
# 0        []      None         2  2015-01-30T02:54:11Z  2018-07-23T05:02:58Z
# 1        []      None        26  2015-01-30T17:25:33Z  2018-07-23T05:02:58Z
# 2        []      None        28  2015-01-30T18:05:27Z  2018-07-23T05:02:58Z
# 3        []      None         4  2015-01-30T20:51:21Z  2018-07-23T05:02:57Z
# 4        []      None         5  2015-01-30T21:28:44Z  2018-07-23T05:02:57Z
#
#               closed_at author_association active_lock_reason  \
# 0  2015-01-31T00:04:06Z               NONE           resolved
# 1  2015-02-07T20:36:47Z               NONE           resolved
# 2  2015-04-01T02:26:12Z               NONE           resolved
# 3  2015-02-07T20:37:20Z        CONTRIBUTOR           resolved
# 4  2015-01-31T00:03:40Z        CONTRIBUTOR           resolved
#
#                                                 body  \
# 0  To build on my machine (OS X 10.9.3) targeting...
# 1  Is it possible to set the status bar to light?...
# 2  Is it possible to have the simulator automatic...
# 3  This is not an issue per se, but something tha...
# 4  I want to implement support for Webpack dev se...
#
#                                            reactions  \
# 0  {'url': 'https://api.github.com/repos/facebook...
# 1  {'url': 'https://api.github.com/repos/facebook...
# 2  {'url': 'https://api.github.com/repos/facebook...
# 3  {'url': 'https://api.github.com/repos/facebook...
# 4  {'url': 'https://api.github.com/repos/facebook...
#
#                                         timeline_url performed_via_github_app  \
# 0  https://api.github.com/repos/facebook/react-na...                     None
# 1  https://api.github.com/repos/facebook/react-na...                     None
# 2  https://api.github.com/repos/facebook/react-na...                     None
# 3  https://api.github.com/repos/facebook/react-na...                     None
# 4  https://api.github.com/repos/facebook/react-na...                     None
#
#   state_reason  score        repository_name issue/pr created_at_timestamp  \
# 0    completed    1.0  facebook/react-native    issue  2015-01-30 02:54:11
# 1    completed    1.0  facebook/react-native    issue  2015-01-30 17:25:33
# 2    completed    1.0  facebook/react-native    issue  2015-01-30 18:05:27
# 3    completed    1.0  facebook/react-native    issue  2015-01-30 20:51:21
# 4    completed    1.0  facebook/react-native    issue  2015-01-30 21:28:44
#
#   closed_at_timestamp  issue_resolution_time  open_since    labels_id  \
# 0 2015-01-31 00:04:06               0.881887         NaN  [998095527]
# 1 2015-02-07 20:36:47               8.132801         NaN  [998095527]
# 2 2015-04-01 02:26:12              60.347743         NaN  [998095527]
# 3 2015-02-07 20:37:20               7.990266         NaN  [998095527]
# 4 2015-01-31 00:03:40               0.107593         NaN  [998095527]
#
#                  labels_node_id             labels_name labels_color  \
# 0  ['MDU6TGFiZWw5OTgwOTU1Mjc=']  ['Resolution: Locked']   ['ffffff']
# 1  ['MDU6TGFiZWw5OTgwOTU1Mjc=']  ['Resolution: Locked']   ['ffffff']
# 2  ['MDU6TGFiZWw5OTgwOTU1Mjc=']  ['Resolution: Locked']   ['ffffff']
# 3  ['MDU6TGFiZWw5OTgwOTU1Mjc=']  ['Resolution: Locked']   ['ffffff']
# 4  ['MDU6TGFiZWw5OTgwOTU1Mjc=']  ['Resolution: Locked']   ['ffffff']
#
#   labels_default                     labels_description
# 0        [False]  ['This issue was locked by the bot.']
# 1        [False]  ['This issue was locked by the bot.']
# 2        [False]  ['This issue was locked by the bot.']
# 3        [False]  ['This issue was locked by the bot.']
# 4        [False]  ['This issue was locked by the bot.']

# %% [markdown]
# Add release tag and date information to the issues

# %%
j = 0
for j in range(issues.shape[0]):
    repository = issues.loc[j,'repository_name']
    created_at = issues.loc[j,'created_at']
    issues.loc[j,'issue_release_tag_name'] = issue_release_tag(stable_releases,repository,created_at)
    issues.loc[j,'issue_release_published_at'] = issue_release_date(stable_releases,repository,created_at)

# %%
j = 0
while j < issues.shape[0]:
    issues.loc[j,'issue_release_published_at_timestamp'] = datetime.strptime(issues.loc[j,'issue_release_published_at'], '%Y-%m-%dT%H:%M:%SZ')
    j = j + 1

# %% [markdown]
# Find total number of issues

# %%
issues.shape[0]
# Out:
# 269188

# %%
issues[issues['issue_resolution_time'] < 0].shape[0]
# Out:
# 44

# %%
issues = issues.drop(issues[issues['issue_resolution_time'] < 0].index)
issues = issues.reset_index(drop=True)
issues.shape[0]
# Out:
# 269144

# %%
issueCount1 = issues.groupby(['repository_name','issue_release_tag_name'])['url'].count().reset_index(name="countOfIssue")
issueCount1.shape[0]
# Out:
# 2847

# %%
issueCount2 = issues.groupby(['repository_name','issue_release_tag_name','issue_release_published_at'])['url'].count().reset_index(name="countOfIssue")
issueCount2.shape[0]
# Out:
# 2847

# %%
ex = pd.merge(issueCount1, issueCount2,  how='left', left_on=['repository_name','issue_release_tag_name'], right_on = ['repository_name','issue_release_tag_name'])
ex.head()
# Out:
#     repository_name issue_release_tag_name  countOfIssue_x  \
# 0  Anuken/Mindustry                    100              42
# 1  Anuken/Mindustry                    101               7
# 2  Anuken/Mindustry                  101.1              16
# 3  Anuken/Mindustry                    102              64
# 4  Anuken/Mindustry                    103              57
#
#   issue_release_published_at  countOfIssue_y
# 0       2019-11-20T01:13:25Z              42
# 1       2019-12-12T23:00:17Z               7
# 2       2019-12-17T22:36:34Z              16
# 3       2019-12-30T00:08:29Z              64
# 4       2020-01-24T17:44:08Z              57

# %%
ex[ex['countOfIssue_x'] != ex['countOfIssue_y']]
# Out:
# Empty DataFrame
# Columns: [repository_name, issue_release_tag_name, countOfIssue_x, issue_release_published_at, countOfIssue_y]
# Index: []

# %%
issueCount = issues.groupby(['repository_name','issue_release_tag_name'])['url'].count().reset_index(name="countOfIssue")
issueCount.shape[0]
# Out:
# 2847

# %%
releaseSummary = pd.merge(releaseSummary, issueCount,  how='left', left_on=['repository_name','tag_name2'], right_on = ['repository_name','issue_release_tag_name'])

# %%
releaseSummary.shape[0]
# Out:
# 3509

# %% [markdown]
# Find avg issue resolution time for closed issues

# %%
issueRes1 = issues[issues['state'] == 'closed'].groupby(['repository_name', 'issue_release_tag_name','issue_release_published_at'])['issue_resolution_time'].mean().reset_index(name="avgResTime")
issueRes1.shape[0]
# Out:
# 2816

# %%
issueRes2 = issues[issues['state'] == 'closed'].groupby(['repository_name', 'issue_release_tag_name'])['issue_resolution_time'].mean().reset_index(name="avgResTime")
issueRes2.shape[0]
# Out:
# 2816

# %%
ex = pd.merge(issueRes1, issueRes2,  how='left', left_on=['repository_name','issue_release_tag_name'], right_on = ['repository_name','issue_release_tag_name'])

# %%
ex[ex['avgResTime_x'] != ex['avgResTime_y']]
# Out:
# Empty DataFrame
# Columns: [repository_name, issue_release_tag_name, issue_release_published_at, avgResTime_x, avgResTime_y]
# Index: []

# %%
issueRes = issues[issues['state'] == 'closed'].groupby(['repository_name', 'issue_release_tag_name'])['issue_resolution_time'].mean().reset_index(name="avgResTime")
issueRes.shape[0]
# Out:
# 2816

# %%
releaseSummary = pd.merge(releaseSummary, issueRes,  how='left', left_on=['repository_name','tag_name2'], right_on = ['repository_name','issue_release_tag_name'])

# %%
releaseSummary.shape[0]
# Out:
# 3509

# %%
releaseSummary = releaseSummary[['tag_name','repository_name','published_at_timestamp','tag_name2','duration_days','countOfIssue','avgResTime']]

# %% [markdown]
# Normalize the number of issues with respect to the duration of the release

# %%
releaseSummary['countOfIssue'] = releaseSummary['countOfIssue'].fillna(0)

# %%
releaseSummary['issueDensity'] = releaseSummary['countOfIssue'] / releaseSummary['duration_days']

# %%
releaseSummary.head()
# Out:
#   tag_name   repository_name published_at_timestamp tag_name2  duration_days  \
# 0      v33  Anuken/Mindustry    2018-03-09 15:14:25        33       4.102558
# 1      v34  Anuken/Mindustry    2018-03-13 17:42:06        34      11.037824
# 2      v35  Anuken/Mindustry    2018-03-24 18:36:34        35       8.017627
# 3      v36  Anuken/Mindustry    2018-04-01 19:01:57        36       1.012917
# 4      v37  Anuken/Mindustry    2018-04-02 19:20:33        37      19.126887
#
#    countOfIssue  avgResTime  issueDensity
# 0           2.0    2.240747      0.487501
# 1           4.0   18.085124      0.362390
# 2           3.0    5.780918      0.374176
# 3           0.0         NaN      0.000000
# 4           4.0   11.284123      0.209130

# %% [markdown]
# ### Overall df

# %% [markdown]
# Design Smells

# %%
c = ['designSmell','smellCount','repository_name','release','info']
design = pd.read_csv('/Users/isdeniz/Documents/results/designCodeSmellsSummary.csv', names=c, dtype={'release': str})
print('shape:',design.shape[0],'unique info:',len(design['info'].unique()))
# Out:
# shape: 43698 unique info: 3509

# %%
design.dropna(subset=['designSmell'], inplace=True)
design.shape[0]
# Out:
# 43679

# %%
pivot_df = design.pivot_table(index=['repository_name', 'release', 'info'], columns='designSmell', values='smellCount', aggfunc='first')
pivot_df.reset_index(inplace=True)

# %%
summary = pd.merge(pivot_df, releaseSummary, how='left', left_on = ['repository_name','release'], right_on = ['repository_name','tag_name2'])

# %%
summary.shape[0]
# Out:
# 3490

# %%
summary[summary['release'] != summary['tag_name2']]
# Out:
# Empty DataFrame
# Columns: [repository_name, release, info, Broken Hierarchy, Broken Modularization, Cyclic Hierarchy, Cyclic-Dependent Modularization, Deep Hierarchy, Deficient Encapsulation, Hub-like Modularization, Imperative Abstraction, Insufficient Modularization, Missing Hierarchy, Multifaceted Abstraction, Multipath Hierarchy, Rebellious Hierarchy, Unexploited Encapsulation, Unnecessary Abstraction, Unutilized Abstraction, Wide Hierarchy, tag_name, published_at_timestamp, tag_name2, duration_days, countOfIssue, avgResTime, issueDensity]
# Index: []

# %%
summary.head()
# Out:
#     repository_name release             info  Broken Hierarchy  \
# 0  Anuken/Mindustry     100    Mindustry-100              62.0
# 1  Anuken/Mindustry     101    Mindustry-101              64.0
# 2  Anuken/Mindustry   101.1  Mindustry-101.1              64.0
# 3  Anuken/Mindustry     102    Mindustry-102              64.0
# 4  Anuken/Mindustry     103    Mindustry-103              64.0
#
#    Broken Modularization  Cyclic Hierarchy  Cyclic-Dependent Modularization  \
# 0                    6.0               NaN                             33.0
# 1                    5.0               NaN                             35.0
# 2                    5.0               NaN                             36.0
# 3                    5.0               NaN                             34.0
# 4                    5.0               NaN                             34.0
#
#    Deep Hierarchy  Deficient Encapsulation  Hub-like Modularization  \
# 0             NaN                    258.0                      NaN
# 1             NaN                    296.0                      NaN
# 2             NaN                    299.0                      NaN
# 3             NaN                    301.0                      NaN
# 4             NaN                    304.0                      NaN
#
#    Imperative Abstraction  Insufficient Modularization  Missing Hierarchy  \
# 0                     8.0                         41.0                3.0
# 1                     8.0                         42.0                3.0
# 2                     8.0                         42.0                3.0
# 3                     8.0                         43.0                3.0
# 4                     8.0                         43.0                3.0
#
#    Multifaceted Abstraction  Multipath Hierarchy  Rebellious Hierarchy  \
# 0                       3.0                  3.0                   1.0
# 1                       4.0                  3.0                   1.0
# 2                       4.0                  3.0                   1.0
# 3                       4.0                  3.0                   1.0
# 4                       4.0                  3.0                   1.0
#
#    Unexploited Encapsulation  Unnecessary Abstraction  Unutilized Abstraction  \
# 0                        2.0                     58.0                   355.0
# 1                        2.0                     50.0                   350.0
# 2                        2.0                     50.0                   346.0
# 3                        2.0                     50.0                   348.0
# 4                        2.0                     48.0                   358.0
#
#    Wide Hierarchy tag_name published_at_timestamp tag_name2  duration_days  \
# 0             2.0     v100    2019-11-20 01:13:25       100      22.907546
# 1             2.0     v101    2019-12-12 23:00:17       101       4.983530
# 2             2.0   v101.1    2019-12-17 22:36:34     101.1      12.063831
# 3             2.0     v102    2019-12-30 00:08:29       102      25.733090
# 4             2.0     v103    2020-01-24 17:44:08       103      18.224977
#
#    countOfIssue  avgResTime  issueDensity
# 0          42.0    4.520398      1.833457
# 1           7.0    0.282001      1.404627
# 2          16.0    0.479111      1.326279
# 3          64.0   10.744183      2.487070
# 4          57.0    1.543117      3.127576

# %%
c = ['Broken Hierarchy', 'Broken Modularization', 'Cyclic Hierarchy', 'Cyclic-Dependent Modularization', 'Deep Hierarchy', 
     'Deficient Encapsulation', 'Hub-like Modularization', 'Imperative Abstraction', 'Insufficient Modularization', 'Missing Hierarchy', 
     'Multifaceted Abstraction', 'Multipath Hierarchy', 'Rebellious Hierarchy', 'Unexploited Encapsulation', 'Unnecessary Abstraction', 
     'Unutilized Abstraction', 'Wide Hierarchy']
i = 0 
while i < len(c):
    summary[c[i]] = summary[c[i]].fillna(0)
    i = i + 1
summary.head()
# Out:
#     repository_name release             info  Broken Hierarchy  \
# 0  Anuken/Mindustry     100    Mindustry-100              62.0
# 1  Anuken/Mindustry     101    Mindustry-101              64.0
# 2  Anuken/Mindustry   101.1  Mindustry-101.1              64.0
# 3  Anuken/Mindustry     102    Mindustry-102              64.0
# 4  Anuken/Mindustry     103    Mindustry-103              64.0
#
#    Broken Modularization  Cyclic Hierarchy  Cyclic-Dependent Modularization  \
# 0                    6.0               0.0                             33.0
# 1                    5.0               0.0                             35.0
# 2                    5.0               0.0                             36.0
# 3                    5.0               0.0                             34.0
# 4                    5.0               0.0                             34.0
#
#    Deep Hierarchy  Deficient Encapsulation  Hub-like Modularization  \
# 0             0.0                    258.0                      0.0
# 1             0.0                    296.0                      0.0
# 2             0.0                    299.0                      0.0
# 3             0.0                    301.0                      0.0
# 4             0.0                    304.0                      0.0
#
#    Imperative Abstraction  Insufficient Modularization  Missing Hierarchy  \
# 0                     8.0                         41.0                3.0
# 1                     8.0                         42.0                3.0
# 2                     8.0                         42.0                3.0
# 3                     8.0                         43.0                3.0
# 4                     8.0                         43.0                3.0
#
#    Multifaceted Abstraction  Multipath Hierarchy  Rebellious Hierarchy  \
# 0                       3.0                  3.0                   1.0
# 1                       4.0                  3.0                   1.0
# 2                       4.0                  3.0                   1.0
# 3                       4.0                  3.0                   1.0
# 4                       4.0                  3.0                   1.0
#
#    Unexploited Encapsulation  Unnecessary Abstraction  Unutilized Abstraction  \
# 0                        2.0                     58.0                   355.0
# 1                        2.0                     50.0                   350.0
# 2                        2.0                     50.0                   346.0
# 3                        2.0                     50.0                   348.0
# 4                        2.0                     48.0                   358.0
#
#    Wide Hierarchy tag_name published_at_timestamp tag_name2  duration_days  \
# 0             2.0     v100    2019-11-20 01:13:25       100      22.907546
# 1             2.0     v101    2019-12-12 23:00:17       101       4.983530
# 2             2.0   v101.1    2019-12-17 22:36:34     101.1      12.063831
# 3             2.0     v102    2019-12-30 00:08:29       102      25.733090
# 4             2.0     v103    2020-01-24 17:44:08       103      18.224977
#
#    countOfIssue  avgResTime  issueDensity
# 0          42.0    4.520398      1.833457
# 1           7.0    0.282001      1.404627
# 2          16.0    0.479111      1.326279
# 3          64.0   10.744183      2.487070
# 4          57.0    1.543117      3.127576

# %%
middle_columns = summary.iloc[:, 3:20]  
summary['totalDesignSmells'] = middle_columns.sum(axis=1)
summary.head()
# Out:
#     repository_name release             info  Broken Hierarchy  \
# 0  Anuken/Mindustry     100    Mindustry-100              62.0
# 1  Anuken/Mindustry     101    Mindustry-101              64.0
# 2  Anuken/Mindustry   101.1  Mindustry-101.1              64.0
# 3  Anuken/Mindustry     102    Mindustry-102              64.0
# 4  Anuken/Mindustry     103    Mindustry-103              64.0
#
#    Broken Modularization  Cyclic Hierarchy  Cyclic-Dependent Modularization  \
# 0                    6.0               0.0                             33.0
# 1                    5.0               0.0                             35.0
# 2                    5.0               0.0                             36.0
# 3                    5.0               0.0                             34.0
# 4                    5.0               0.0                             34.0
#
#    Deep Hierarchy  Deficient Encapsulation  Hub-like Modularization  \
# 0             0.0                    258.0                      0.0
# 1             0.0                    296.0                      0.0
# 2             0.0                    299.0                      0.0
# 3             0.0                    301.0                      0.0
# 4             0.0                    304.0                      0.0
#
#    Imperative Abstraction  Insufficient Modularization  Missing Hierarchy  \
# 0                     8.0                         41.0                3.0
# 1                     8.0                         42.0                3.0
# 2                     8.0                         42.0                3.0
# 3                     8.0                         43.0                3.0
# 4                     8.0                         43.0                3.0
#
#    Multifaceted Abstraction  Multipath Hierarchy  Rebellious Hierarchy  \
# 0                       3.0                  3.0                   1.0
# 1                       4.0                  3.0                   1.0
# 2                       4.0                  3.0                   1.0
# 3                       4.0                  3.0                   1.0
# 4                       4.0                  3.0                   1.0
#
#    Unexploited Encapsulation  Unnecessary Abstraction  Unutilized Abstraction  \
# 0                        2.0                     58.0                   355.0
# 1                        2.0                     50.0                   350.0
# 2                        2.0                     50.0                   346.0
# 3                        2.0                     50.0                   348.0
# 4                        2.0                     48.0                   358.0
#
#    Wide Hierarchy tag_name published_at_timestamp tag_name2  duration_days  \
# 0             2.0     v100    2019-11-20 01:13:25       100      22.907546
# 1             2.0     v101    2019-12-12 23:00:17       101       4.983530
# 2             2.0   v101.1    2019-12-17 22:36:34     101.1      12.063831
# 3             2.0     v102    2019-12-30 00:08:29       102      25.733090
# 4             2.0     v103    2020-01-24 17:44:08       103      18.224977
#
#    countOfIssue  avgResTime  issueDensity  totalDesignSmells
# 0          42.0    4.520398      1.833457              835.0
# 1           7.0    0.282001      1.404627              865.0
# 2          16.0    0.479111      1.326279              865.0
# 3          64.0   10.744183      2.487070              868.0
# 4          57.0    1.543117      3.127576              879.0

# %% [markdown]
# Implementation Smells

# %%
c = ['implementationSmell','smellCount','repository_name','release','info']
implementation = pd.read_csv('/Users/isdeniz/Documents/results/implementationCodeSmellsSummary.csv', names=c, dtype={'release': str})
print('shape:',implementation.shape[0],'unique info:',len(implementation['info'].unique()))
# Out:
# shape: 32051 unique info: 3509

# %%
implementation.dropna(subset=['implementationSmell'], inplace=True)
implementation.shape[0]
# Out:
# 32032

# %%
pivot_df = implementation.pivot_table(index=['repository_name', 'release', 'info'], columns='implementationSmell', values='smellCount', aggfunc='first')
pivot_df.reset_index(inplace=True)

# %%
summary = pd.merge(pivot_df, summary, how='left', left_on = ['repository_name','release'], right_on = ['repository_name','tag_name2'])
summary.head()
# Out:
#     repository_name release_x           info_x  \
# 0  Anuken/Mindustry       100    Mindustry-100
# 1  Anuken/Mindustry       101    Mindustry-101
# 2  Anuken/Mindustry     101.1  Mindustry-101.1
# 3  Anuken/Mindustry       102    Mindustry-102
# 4  Anuken/Mindustry       103    Mindustry-103
#
#    Abstract Function Call From Constructor  Complex Conditional  \
# 0                                      1.0                300.0
# 1                                      1.0                305.0
# 2                                      1.0                307.0
# 3                                      1.0                307.0
# 4                                      1.0                314.0
#
#    Complex Method  Empty catch clause  Long Identifier  Long Method  \
# 0           157.0                10.0              NaN         31.0
# 1           160.0                14.0              NaN         32.0
# 2           161.0                13.0              NaN         33.0
# 3           161.0                13.0              NaN         34.0
# 4           164.0                14.0              NaN         34.0
#
#    Long Parameter List  Long Statement  Magic Number  Missing default  \
# 0                161.0           719.0        6564.0              1.0
# 1                161.0           736.0        6574.0              1.0
# 2                161.0           734.0        6538.0              1.0
# 3                165.0           730.0        6573.0              1.0
# 4                168.0           763.0        6672.0              1.0
#
#   release_y           info_y  Broken Hierarchy  Broken Modularization  \
# 0       100    Mindustry-100              62.0                    6.0
# 1       101    Mindustry-101              64.0                    5.0
# 2     101.1  Mindustry-101.1              64.0                    5.0
# 3       102    Mindustry-102              64.0                    5.0
# 4       103    Mindustry-103              64.0                    5.0
#
#    Cyclic Hierarchy  Cyclic-Dependent Modularization  Deep Hierarchy  \
# 0               0.0                             33.0             0.0
# 1               0.0                             35.0             0.0
# 2               0.0                             36.0             0.0
# 3               0.0                             34.0             0.0
# 4               0.0                             34.0             0.0
#
#    Deficient Encapsulation  Hub-like Modularization  Imperative Abstraction  \
# 0                    258.0                      0.0                     8.0
# 1                    296.0                      0.0                     8.0
# 2                    299.0                      0.0                     8.0
# 3                    301.0                      0.0                     8.0
# 4                    304.0                      0.0                     8.0
#
#    Insufficient Modularization  Missing Hierarchy  Multifaceted Abstraction  \
# 0                         41.0                3.0                       3.0
# 1                         42.0                3.0                       4.0
# 2                         42.0                3.0                       4.0
# 3                         43.0                3.0                       4.0
# 4                         43.0                3.0                       4.0
#
#    Multipath Hierarchy  Rebellious Hierarchy  Unexploited Encapsulation  \
# 0                  3.0                   1.0                        2.0
# 1                  3.0                   1.0                        2.0
# 2                  3.0                   1.0                        2.0
# 3                  3.0                   1.0                        2.0
# 4                  3.0                   1.0                        2.0
#
#    Unnecessary Abstraction  Unutilized Abstraction  Wide Hierarchy tag_name  \
# 0                     58.0                   355.0             2.0     v100
# 1                     50.0                   350.0             2.0     v101
# 2                     50.0                   346.0             2.0   v101.1
# 3                     50.0                   348.0             2.0     v102
# 4                     48.0                   358.0             2.0     v103
#
#   published_at_timestamp tag_name2  duration_days  countOfIssue  avgResTime  \
# 0    2019-11-20 01:13:25       100      22.907546          42.0    4.520398
# 1    2019-12-12 23:00:17       101       4.983530           7.0    0.282001
# 2    2019-12-17 22:36:34     101.1      12.063831          16.0    0.479111
# 3    2019-12-30 00:08:29       102      25.733090          64.0   10.744183
# 4    2020-01-24 17:44:08       103      18.224977          57.0    1.543117
#
#    issueDensity  totalDesignSmells
# 0      1.833457              835.0
# 1      1.404627              865.0
# 2      1.326279              865.0
# 3      2.487070              868.0
# 4      3.127576              879.0

# %%
summary.shape[0]
# Out:
# 3490

# %%
summary[summary['release_x'] != summary['release_y']]
# Out:
# Empty DataFrame
# Columns: [repository_name, release_x, info_x, Abstract Function Call From Constructor, Complex Conditional, Complex Method, Empty catch clause, Long Identifier, Long Method, Long Parameter List, Long Statement, Magic Number, Missing default, release_y, info_y, Broken Hierarchy, Broken Modularization, Cyclic Hierarchy, Cyclic-Dependent Modularization, Deep Hierarchy, Deficient Encapsulation, Hub-like Modularization, Imperative Abstraction, Insufficient Modularization, Missing Hierarchy, Multifaceted Abstraction, Multipath Hierarchy, Rebellious Hierarchy, Unexploited Encapsulation, Unnecessary Abstraction, Unutilized Abstraction, Wide Hierarchy, tag_name, published_at_timestamp, tag_name2, duration_days, countOfIssue, avgResTime, issueDensity, totalDesignSmells]
# Index: []

# %%
summary = summary.drop(columns=['release_y','info_y'])
summary.rename(columns={'release_x': 'release'}, inplace=True)
summary.rename(columns={'info_x': 'info'}, inplace=True)

# %%
c = ['Abstract Function Call From Constructor', 'Complex Conditional', 'Complex Method', 'Empty catch clause', 'Long Identifier', 
     'Long Method', 'Long Parameter List', 'Long Statement', 'Magic Number', 'Missing default']
i = 0 
while i < len(c):
    summary[c[i]] = summary[c[i]].fillna(0)
    i = i + 1
summary.head()
# Out:
#     repository_name release             info  \
# 0  Anuken/Mindustry     100    Mindustry-100
# 1  Anuken/Mindustry     101    Mindustry-101
# 2  Anuken/Mindustry   101.1  Mindustry-101.1
# 3  Anuken/Mindustry     102    Mindustry-102
# 4  Anuken/Mindustry     103    Mindustry-103
#
#    Abstract Function Call From Constructor  Complex Conditional  \
# 0                                      1.0                300.0
# 1                                      1.0                305.0
# 2                                      1.0                307.0
# 3                                      1.0                307.0
# 4                                      1.0                314.0
#
#    Complex Method  Empty catch clause  Long Identifier  Long Method  \
# 0           157.0                10.0              0.0         31.0
# 1           160.0                14.0              0.0         32.0
# 2           161.0                13.0              0.0         33.0
# 3           161.0                13.0              0.0         34.0
# 4           164.0                14.0              0.0         34.0
#
#    Long Parameter List  Long Statement  Magic Number  Missing default  \
# 0                161.0           719.0        6564.0              1.0
# 1                161.0           736.0        6574.0              1.0
# 2                161.0           734.0        6538.0              1.0
# 3                165.0           730.0        6573.0              1.0
# 4                168.0           763.0        6672.0              1.0
#
#    Broken Hierarchy  Broken Modularization  Cyclic Hierarchy  \
# 0              62.0                    6.0               0.0
# 1              64.0                    5.0               0.0
# 2              64.0                    5.0               0.0
# 3              64.0                    5.0               0.0
# 4              64.0                    5.0               0.0
#
#    Cyclic-Dependent Modularization  Deep Hierarchy  Deficient Encapsulation  \
# 0                             33.0             0.0                    258.0
# 1                             35.0             0.0                    296.0
# 2                             36.0             0.0                    299.0
# 3                             34.0             0.0                    301.0
# 4                             34.0             0.0                    304.0
#
#    Hub-like Modularization  Imperative Abstraction  \
# 0                      0.0                     8.0
# 1                      0.0                     8.0
# 2                      0.0                     8.0
# 3                      0.0                     8.0
# 4                      0.0                     8.0
#
#    Insufficient Modularization  Missing Hierarchy  Multifaceted Abstraction  \
# 0                         41.0                3.0                       3.0
# 1                         42.0                3.0                       4.0
# 2                         42.0                3.0                       4.0
# 3                         43.0                3.0                       4.0
# 4                         43.0                3.0                       4.0
#
#    Multipath Hierarchy  Rebellious Hierarchy  Unexploited Encapsulation  \
# 0                  3.0                   1.0                        2.0
# 1                  3.0                   1.0                        2.0
# 2                  3.0                   1.0                        2.0
# 3                  3.0                   1.0                        2.0
# 4                  3.0                   1.0                        2.0
#
#    Unnecessary Abstraction  Unutilized Abstraction  Wide Hierarchy tag_name  \
# 0                     58.0                   355.0             2.0     v100
# 1                     50.0                   350.0             2.0     v101
# 2                     50.0                   346.0             2.0   v101.1
# 3                     50.0                   348.0             2.0     v102
# 4                     48.0                   358.0             2.0     v103
#
#   published_at_timestamp tag_name2  duration_days  countOfIssue  avgResTime  \
# 0    2019-11-20 01:13:25       100      22.907546          42.0    4.520398
# 1    2019-12-12 23:00:17       101       4.983530           7.0    0.282001
# 2    2019-12-17 22:36:34     101.1      12.063831          16.0    0.479111
# 3    2019-12-30 00:08:29       102      25.733090          64.0   10.744183
# 4    2020-01-24 17:44:08       103      18.224977          57.0    1.543117
#
#    issueDensity  totalDesignSmells
# 0      1.833457              835.0
# 1      1.404627              865.0
# 2      1.326279              865.0
# 3      2.487070              868.0
# 4      3.127576              879.0

# %%
middle_columns = summary.iloc[:, 3:13]  
summary['totalImplementationSmells'] = middle_columns.sum(axis=1)
summary.head()
# Out:
#     repository_name release             info  \
# 0  Anuken/Mindustry     100    Mindustry-100
# 1  Anuken/Mindustry     101    Mindustry-101
# 2  Anuken/Mindustry   101.1  Mindustry-101.1
# 3  Anuken/Mindustry     102    Mindustry-102
# 4  Anuken/Mindustry     103    Mindustry-103
#
#    Abstract Function Call From Constructor  Complex Conditional  \
# 0                                      1.0                300.0
# 1                                      1.0                305.0
# 2                                      1.0                307.0
# 3                                      1.0                307.0
# 4                                      1.0                314.0
#
#    Complex Method  Empty catch clause  Long Identifier  Long Method  \
# 0           157.0                10.0              0.0         31.0
# 1           160.0                14.0              0.0         32.0
# 2           161.0                13.0              0.0         33.0
# 3           161.0                13.0              0.0         34.0
# 4           164.0                14.0              0.0         34.0
#
#    Long Parameter List  Long Statement  Magic Number  Missing default  \
# 0                161.0           719.0        6564.0              1.0
# 1                161.0           736.0        6574.0              1.0
# 2                161.0           734.0        6538.0              1.0
# 3                165.0           730.0        6573.0              1.0
# 4                168.0           763.0        6672.0              1.0
#
#    Broken Hierarchy  Broken Modularization  Cyclic Hierarchy  \
# 0              62.0                    6.0               0.0
# 1              64.0                    5.0               0.0
# 2              64.0                    5.0               0.0
# 3              64.0                    5.0               0.0
# 4              64.0                    5.0               0.0
#
#    Cyclic-Dependent Modularization  Deep Hierarchy  Deficient Encapsulation  \
# 0                             33.0             0.0                    258.0
# 1                             35.0             0.0                    296.0
# 2                             36.0             0.0                    299.0
# 3                             34.0             0.0                    301.0
# 4                             34.0             0.0                    304.0
#
#    Hub-like Modularization  Imperative Abstraction  \
# 0                      0.0                     8.0
# 1                      0.0                     8.0
# 2                      0.0                     8.0
# 3                      0.0                     8.0
# 4                      0.0                     8.0
#
#    Insufficient Modularization  Missing Hierarchy  Multifaceted Abstraction  \
# 0                         41.0                3.0                       3.0
# 1                         42.0                3.0                       4.0
# 2                         42.0                3.0                       4.0
# 3                         43.0                3.0                       4.0
# 4                         43.0                3.0                       4.0
#
#    Multipath Hierarchy  Rebellious Hierarchy  Unexploited Encapsulation  \
# 0                  3.0                   1.0                        2.0
# 1                  3.0                   1.0                        2.0
# 2                  3.0                   1.0                        2.0
# 3                  3.0                   1.0                        2.0
# 4                  3.0                   1.0                        2.0
#
#    Unnecessary Abstraction  Unutilized Abstraction  Wide Hierarchy tag_name  \
# 0                     58.0                   355.0             2.0     v100
# 1                     50.0                   350.0             2.0     v101
# 2                     50.0                   346.0             2.0   v101.1
# 3                     50.0                   348.0             2.0     v102
# 4                     48.0                   358.0             2.0     v103
#
#   published_at_timestamp tag_name2  duration_days  countOfIssue  avgResTime  \
# 0    2019-11-20 01:13:25       100      22.907546          42.0    4.520398
# 1    2019-12-12 23:00:17       101       4.983530           7.0    0.282001
# 2    2019-12-17 22:36:34     101.1      12.063831          16.0    0.479111
# 3    2019-12-30 00:08:29       102      25.733090          64.0   10.744183
# 4    2020-01-24 17:44:08       103      18.224977          57.0    1.543117
#
#    issueDensity  totalDesignSmells  totalImplementationSmells
# 0      1.833457              835.0                     7944.0
# 1      1.404627              865.0                     7984.0
# 2      1.326279              865.0                     7949.0
# 3      2.487070              868.0                     7985.0
# 4      3.127576              879.0                     8131.0

# %%
na_values = summary[summary['avgResTime'].isna()]
na_values.shape[0]
# Out:
# 713

# %%
rows_with_na = summary[summary.isna().any(axis=1)]
rows_with_na.shape[0]
# Out:
# 713

# %%
r = summary['repository_name'].unique()

repository = r[0]
summaryR = summary[summary['repository_name'] == repository]
summaryR['published_at_timestamp'] = pd.to_datetime(summaryR['published_at_timestamp'])
summaryR = summaryR.sort_values(by='published_at_timestamp')
plt.figure(figsize=(20, 8))
plt.scatter(summaryR['published_at_timestamp'], summaryR['totalDesignSmells'], marker='o', color='cornflowerblue', label='totalDesignSmells')
plt.scatter(summaryR['published_at_timestamp'], summaryR['totalImplementationSmells'], marker='o', color='darkorange', label='totalImplementationSmells')
plt.scatter(summaryR['published_at_timestamp'], summaryR['countOfIssue'], marker='o', color='yellow', label='countOfIssue')
plt.scatter(summaryR['published_at_timestamp'], summaryR['issueDensity'], marker='o', color='red', label='issueDensity')
plt.scatter(summaryR['published_at_timestamp'], summaryR['avgResTime'], marker='o', color='limegreen', label='avgResTime')
plt.title(f'{repository},{summaryR.shape[0]}')
plt.xlabel('Timestamp')
plt.ylabel('number of occurrence')
plt.grid(True)
plt.legend()
plt.show()

# %%
r = summary['repository_name'].unique()

repository = r[0]
summaryR = summary[summary['repository_name'] == repository]
summaryR['published_at_timestamp'] = pd.to_datetime(summaryR['published_at_timestamp'])
summaryR = summaryR.sort_values(by='published_at_timestamp')
plt.figure(figsize=(20, 8))
plt.scatter(summaryR['published_at_timestamp'], summaryR['totalDesignSmells'], marker='o', color='cornflowerblue', label='totalDesignSmells')
#plt.scatter(summaryR['published_at_timestamp'], summaryR['totalImplementationSmells'], marker='o', color='darkorange', label='totalImplementationSmells')
plt.scatter(summaryR['published_at_timestamp'], summaryR['countOfIssue'], marker='o', color='yellow', label='countOfIssue')
plt.scatter(summaryR['published_at_timestamp'], summaryR['issueDensity'], marker='o', color='red', label='issueDensity')
plt.scatter(summaryR['published_at_timestamp'], summaryR['avgResTime'], marker='o', color='limegreen', label='avgResTime')
plt.title(f'{repository},{summaryR.shape[0]}')
plt.xlabel('Timestamp')
plt.ylabel('number of occurrence')
plt.grid(True)
plt.legend()
plt.show()

# %%
r = summary['repository_name'].unique()

repository = r[0]
summaryR = summary[summary['repository_name'] == repository]
summaryR['published_at_timestamp'] = pd.to_datetime(summaryR['published_at_timestamp'])
summaryR = summaryR.sort_values(by='published_at_timestamp')
plt.figure(figsize=(20, 8))
#plt.scatter(summaryR['published_at_timestamp'], summaryR['totalDesignSmells'], marker='o', color='cornflowerblue', label='totalDesignSmells')
#plt.scatter(summaryR['published_at_timestamp'], summaryR['totalImplementationSmells'], marker='o', color='darkorange', label='totalImplementationSmells')
#plt.scatter(summaryR['published_at_timestamp'], summaryR['countOfIssue'], marker='o', color='yellow', label='countOfIssue')
plt.scatter(summaryR['published_at_timestamp'], summaryR['issueDensity'], marker='o', color='red', label='issueDensity')
plt.scatter(summaryR['published_at_timestamp'], summaryR['avgResTime'], marker='o', color='limegreen', label='avgResTime')
plt.title(f'{repository},{summaryR.shape[0]}')
plt.xlabel('Timestamp')
plt.ylabel('number of occurrence')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# Method Metrics

# %%
c = ['LOCminM','LOCmaxM','LOCsumM','CCminM','CCmaxM','CCsumM','PCminM','PCmaxM','PCsumM','methodCount','repository_name','release','info']
method = pd.read_csv('/Users/isdeniz/Documents/results/methodMetricsSummary.csv', names=c, dtype={'release': str})
print('shape:',method.shape[0],'unique info:',len(method['info'].unique()))
# Out:
# shape: 3509 unique info: 3509

# %%
method.dropna(subset=['LOCminM'], inplace=True)
method.shape[0]
# Out:
# 3490

# %%
summary = pd.merge(method, summary, how='left', left_on = ['repository_name','release'], right_on = ['repository_name','tag_name2'])
summary.head()
# Out:
#    LOCminM  LOCmaxM  LOCsumM  CCminM  CCmaxM   CCsumM  PCminM  PCmaxM  \
# 0      0.0    227.0  97801.0     1.0    45.0  20170.0     0.0    15.0
# 1      0.0    272.0  84466.0     1.0    66.0  19850.0     0.0    12.0
# 2      0.0    227.0  79411.0     1.0    67.0  19677.0     0.0    15.0
# 3      0.0    198.0  32419.0     1.0    45.0   7886.0     0.0    10.0
# 4      0.0    104.0  19618.0     1.0    21.0   5268.0     0.0    11.0
#
#     PCsumM  methodCount        repository_name    release_x  \
# 0  13392.0      12760.0          alibaba/nacos        2.2.3
# 1   9659.0       9010.0           apache/dubbo  dubbo-2.6.4
# 2   9814.0       9196.0  pinpoint-apm/pinpoint        1.1.2
# 3   3850.0       3483.0    TeamNewPipe/NewPipe      0.21.12
# 4   2956.0       2590.0    TeamNewPipe/NewPipe       0.13.4
#
#               info_x    release_y             info_y  \
# 0        nacos-2.2.3        2.2.3        nacos-2.2.3
# 1  dubbo-dubbo-2.6.4  dubbo-2.6.4  dubbo-dubbo-2.6.4
# 2     pinpoint-1.1.2        1.1.2     pinpoint-1.1.2
# 3    NewPipe-0.21.12      0.21.12    NewPipe-0.21.12
# 4     NewPipe-0.13.4       0.13.4     NewPipe-0.13.4
#
#    Abstract Function Call From Constructor  Complex Conditional  \
# 0                                      1.0                 63.0
# 1                                      2.0                165.0
# 2                                      0.0                 33.0
# 3                                      0.0                143.0
# 4                                      0.0                 84.0
#
#    Complex Method  Empty catch clause  Long Identifier  Long Method  \
# 0           105.0               139.0            226.0          9.0
# 1           217.0               235.0              5.0         25.0
# 2           293.0                79.0            162.0         34.0
# 3           110.0                24.0             35.0          5.0
# 4            61.0                12.0             13.0          1.0
#
#    Long Parameter List  Long Statement  Magic Number  Missing default  \
# 0                514.0          2520.0        2422.0             48.0
# 1                 71.0          1152.0        2203.0            151.0
# 2                175.0           814.0        2574.0            102.0
# 3                 41.0           733.0         947.0             85.0
# 4                 48.0           505.0         456.0             54.0
#
#    Broken Hierarchy  Broken Modularization  Cyclic Hierarchy  \
# 0             103.0                   38.0               0.0
# 1              53.0                    1.0               0.0
# 2              86.0                    5.0               0.0
# 3              24.0                    6.0               0.0
# 4              12.0                    3.0               0.0
#
#    Cyclic-Dependent Modularization  Deep Hierarchy  Deficient Encapsulation  \
# 0                             99.0             0.0                    219.0
# 1                             35.0             0.0                    161.0
# 2                             32.0             0.0                    174.0
# 3                             86.0             0.0                    115.0
# 4                             51.0             0.0                     73.0
#
#    Hub-like Modularization  Imperative Abstraction  \
# 0                      1.0                     2.0
# 1                      0.0                    15.0
# 2                      0.0                     1.0
# 3                      1.0                     0.0
# 4                      0.0                     0.0
#
#    Insufficient Modularization  Missing Hierarchy  Multifaceted Abstraction  \
# 0                         88.0                3.0                       3.0
# 1                        127.0                2.0                       0.0
# 2                         69.0                2.0                       1.0
# 3                         32.0                2.0                       0.0
# 4                         25.0                1.0                       0.0
#
#    Multipath Hierarchy  Rebellious Hierarchy  Unexploited Encapsulation  \
# 0                  0.0                   0.0                        2.0
# 1                  1.0                   0.0                        0.0
# 2                  2.0                   0.0                        1.0
# 3                  0.0                   2.0                        0.0
# 4                  0.0                   2.0                        0.0
#
#    Unnecessary Abstraction  Unutilized Abstraction  Wide Hierarchy  \
# 0                     82.0                  1066.0             0.0
# 1                     53.0                   879.0             0.0
# 2                     36.0                   910.0             1.0
# 3                     19.0                   159.0             0.0
# 4                      1.0                   107.0             0.0
#
#       tag_name published_at_timestamp    tag_name2  duration_days  \
# 0        2.2.3    2023-05-25 07:40:58        2.2.3       0.019954
# 1  dubbo-2.6.4    2018-10-08 07:26:15  dubbo-2.6.4      45.809178
# 2        1.1.2    2015-11-24 09:10:58        1.1.2       1.813681
# 3     v0.21.12    2021-10-12 18:40:43      0.21.12       9.086262
# 4      v0.13.4    2018-05-25 16:42:28       0.13.4      10.109248
#
#    countOfIssue  avgResTime  issueDensity  totalDesignSmells  \
# 0           0.0         NaN      0.000000             1706.0
# 1          99.0   77.119970      2.161139             1327.0
# 2           5.0   14.895641      2.756825             1320.0
# 3          45.0   35.751292      4.952532              446.0
# 4          24.0  351.621116      2.374064              275.0
#
#    totalImplementationSmells
# 0                     6047.0
# 1                     4226.0
# 2                     4266.0
# 3                     2123.0
# 4                     1234.0

# %%
summary[summary['release_x'] != summary['release_y']]
# Out:
# Empty DataFrame
# Columns: [LOCminM, LOCmaxM, LOCsumM, CCminM, CCmaxM, CCsumM, PCminM, PCmaxM, PCsumM, methodCount, repository_name, release_x, info_x, release_y, info_y, Abstract Function Call From Constructor, Complex Conditional, Complex Method, Empty catch clause, Long Identifier, Long Method, Long Parameter List, Long Statement, Magic Number, Missing default, Broken Hierarchy, Broken Modularization, Cyclic Hierarchy, Cyclic-Dependent Modularization, Deep Hierarchy, Deficient Encapsulation, Hub-like Modularization, Imperative Abstraction, Insufficient Modularization, Missing Hierarchy, Multifaceted Abstraction, Multipath Hierarchy, Rebellious Hierarchy, Unexploited Encapsulation, Unnecessary Abstraction, Unutilized Abstraction, Wide Hierarchy, tag_name, published_at_timestamp, tag_name2, duration_days, countOfIssue, avgResTime, issueDensity, totalDesignSmells, totalImplementationSmells]
# Index: []

# %%
summary = summary.drop(columns=['release_y','info_y'])
summary.rename(columns={'release_x': 'release'}, inplace=True)
summary.rename(columns={'info_x': 'info'}, inplace=True)

# %%
summary.head()
# Out:
#    LOCminM  LOCmaxM  LOCsumM  CCminM  CCmaxM   CCsumM  PCminM  PCmaxM  \
# 0      0.0    227.0  97801.0     1.0    45.0  20170.0     0.0    15.0
# 1      0.0    272.0  84466.0     1.0    66.0  19850.0     0.0    12.0
# 2      0.0    227.0  79411.0     1.0    67.0  19677.0     0.0    15.0
# 3      0.0    198.0  32419.0     1.0    45.0   7886.0     0.0    10.0
# 4      0.0    104.0  19618.0     1.0    21.0   5268.0     0.0    11.0
#
#     PCsumM  methodCount        repository_name      release  \
# 0  13392.0      12760.0          alibaba/nacos        2.2.3
# 1   9659.0       9010.0           apache/dubbo  dubbo-2.6.4
# 2   9814.0       9196.0  pinpoint-apm/pinpoint        1.1.2
# 3   3850.0       3483.0    TeamNewPipe/NewPipe      0.21.12
# 4   2956.0       2590.0    TeamNewPipe/NewPipe       0.13.4
#
#                 info  Abstract Function Call From Constructor  \
# 0        nacos-2.2.3                                      1.0
# 1  dubbo-dubbo-2.6.4                                      2.0
# 2     pinpoint-1.1.2                                      0.0
# 3    NewPipe-0.21.12                                      0.0
# 4     NewPipe-0.13.4                                      0.0
#
#    Complex Conditional  Complex Method  Empty catch clause  Long Identifier  \
# 0                 63.0           105.0               139.0            226.0
# 1                165.0           217.0               235.0              5.0
# 2                 33.0           293.0                79.0            162.0
# 3                143.0           110.0                24.0             35.0
# 4                 84.0            61.0                12.0             13.0
#
#    Long Method  Long Parameter List  Long Statement  Magic Number  \
# 0          9.0                514.0          2520.0        2422.0
# 1         25.0                 71.0          1152.0        2203.0
# 2         34.0                175.0           814.0        2574.0
# 3          5.0                 41.0           733.0         947.0
# 4          1.0                 48.0           505.0         456.0
#
#    Missing default  Broken Hierarchy  Broken Modularization  Cyclic Hierarchy  \
# 0             48.0             103.0                   38.0               0.0
# 1            151.0              53.0                    1.0               0.0
# 2            102.0              86.0                    5.0               0.0
# 3             85.0              24.0                    6.0               0.0
# 4             54.0              12.0                    3.0               0.0
#
#    Cyclic-Dependent Modularization  Deep Hierarchy  Deficient Encapsulation  \
# 0                             99.0             0.0                    219.0
# 1                             35.0             0.0                    161.0
# 2                             32.0             0.0                    174.0
# 3                             86.0             0.0                    115.0
# 4                             51.0             0.0                     73.0
#
#    Hub-like Modularization  Imperative Abstraction  \
# 0                      1.0                     2.0
# 1                      0.0                    15.0
# 2                      0.0                     1.0
# 3                      1.0                     0.0
# 4                      0.0                     0.0
#
#    Insufficient Modularization  Missing Hierarchy  Multifaceted Abstraction  \
# 0                         88.0                3.0                       3.0
# 1                        127.0                2.0                       0.0
# 2                         69.0                2.0                       1.0
# 3                         32.0                2.0                       0.0
# 4                         25.0                1.0                       0.0
#
#    Multipath Hierarchy  Rebellious Hierarchy  Unexploited Encapsulation  \
# 0                  0.0                   0.0                        2.0
# 1                  1.0                   0.0                        0.0
# 2                  2.0                   0.0                        1.0
# 3                  0.0                   2.0                        0.0
# 4                  0.0                   2.0                        0.0
#
#    Unnecessary Abstraction  Unutilized Abstraction  Wide Hierarchy  \
# 0                     82.0                  1066.0             0.0
# 1                     53.0                   879.0             0.0
# 2                     36.0                   910.0             1.0
# 3                     19.0                   159.0             0.0
# 4                      1.0                   107.0             0.0
#
#       tag_name published_at_timestamp    tag_name2  duration_days  \
# 0        2.2.3    2023-05-25 07:40:58        2.2.3       0.019954
# 1  dubbo-2.6.4    2018-10-08 07:26:15  dubbo-2.6.4      45.809178
# 2        1.1.2    2015-11-24 09:10:58        1.1.2       1.813681
# 3     v0.21.12    2021-10-12 18:40:43      0.21.12       9.086262
# 4      v0.13.4    2018-05-25 16:42:28       0.13.4      10.109248
#
#    countOfIssue  avgResTime  issueDensity  totalDesignSmells  \
# 0           0.0         NaN      0.000000             1706.0
# 1          99.0   77.119970      2.161139             1327.0
# 2           5.0   14.895641      2.756825             1320.0
# 3          45.0   35.751292      4.952532              446.0
# 4          24.0  351.621116      2.374064              275.0
#
#    totalImplementationSmells
# 0                     6047.0
# 1                     4226.0
# 2                     4266.0
# 3                     2123.0
# 4                     1234.0

# %%
rows_with_na = summary[summary.isna().any(axis=1)]
rows_with_na.shape[0]
# Out:
# 713

# %% [markdown]
# Type Metrics

# %%
c = ['NOFminT','NOFmaxT','NOFsumT', 
     'NOPFminT','NOPFmaxT','NOPFsumT',
     'NOMminT','NOMmaxT','NOMsumT',
     'NOPMminT','NOPMmaxT','NOPMsumT',
     'LOCminT','LOCmaxT','LOCsumT',
     'WMCminT','WMCmaxT','WMCsumT',
     'NCminT','NCmaxT','NCsumT',
     'DITminT','DITmaxT','DITsumT',
     'LCOMminT','LCOMmaxT','LCOMsumT',
     'FANINminT','FANINmaxT','FANINsumT',
     'FANOUTminT','FANOUTmaxT','FANOUTsumT',
     'typeCount','repository_name','release','info']
type = pd.read_csv('/Users/isdeniz/Documents/results/typeMetricsSummary.csv', names=c, dtype={'release': str})
print('shape:',type.shape[0],'unique info:',len(type['info'].unique()))
# Out:
# shape: 3509 unique info: 3509

# %%
type.dropna(subset=['NOFminT'], inplace=True)
type.shape[0]
# Out:
# 3490

# %%
summary = pd.merge(type, summary, how='left', left_on = ['repository_name','release'], right_on = ['repository_name','tag_name2'])

# %%
summary[summary['release_x'] != summary['release_y']]
# Out:
# Empty DataFrame
# Columns: [NOFminT, NOFmaxT, NOFsumT, NOPFminT, NOPFmaxT, NOPFsumT, NOMminT, NOMmaxT, NOMsumT, NOPMminT, NOPMmaxT, NOPMsumT, LOCminT, LOCmaxT, LOCsumT, WMCminT, WMCmaxT, WMCsumT, NCminT, NCmaxT, NCsumT, DITminT, DITmaxT, DITsumT, LCOMminT, LCOMmaxT, LCOMsumT, FANINminT, FANINmaxT, FANINsumT, FANOUTminT, FANOUTmaxT, FANOUTsumT, typeCount, repository_name, release_x, info_x, LOCminM, LOCmaxM, LOCsumM, CCminM, CCmaxM, CCsumM, PCminM, PCmaxM, PCsumM, methodCount, release_y, info_y, Abstract Function Call From Constructor, Complex Conditional, Complex Method, Empty catch clause, Long Identifier, Long Method, Long Parameter List, Long Statement, Magic Number, Missing default, Broken Hierarchy, Broken Modularization, Cyclic Hierarchy, Cyclic-Dependent Modularization, Deep Hierarchy, Deficient Encapsulation, Hub-like Modularization, Imperative Abstraction, Insufficient Modularization, Missing Hierarchy, Multifaceted Abstraction, Multipath Hierarchy, Rebellious Hierarchy, Unexploited Encapsulation, Unnecessary Abstraction, Unutilized Abstraction, Wide Hierarchy, tag_name, published_at_timestamp, tag_name2, duration_days, countOfIssue, avgResTime, issueDensity, totalDesignSmells, totalImplementationSmells]
# Index: []

# %%
summary.shape[0]
# Out:
# 3490

# %%
summary.head()
# Out:
#    NOFminT  NOFmaxT  NOFsumT  NOPFminT  NOPFmaxT  NOPFsumT  NOMminT  NOMmaxT  \
# 0      0.0     92.0   6724.0       0.0      92.0    1175.0      0.0    110.0
# 1      0.0    267.0   3894.0       0.0     267.0     751.0      0.0    515.0
# 2      0.0    109.0   4282.0       0.0      52.0     456.0      0.0    144.0
# 3      0.0    108.0   2111.0       0.0      37.0     407.0      0.0    245.0
# 4      0.0     54.0   1364.0       0.0      17.0     300.0      0.0     94.0
#
#    NOMsumT  NOPMminT  NOPMmaxT  NOPMsumT  LOCminT  LOCmaxT   LOCsumT  WMCminT  \
# 0  13998.0       0.0     108.0   11633.0      2.0   1862.0  133961.0      0.0
# 1  11824.0       0.0     457.0    9904.0      2.0   3827.0  100175.0      0.0
# 2  10302.0       0.0     141.0    8014.0      2.0   2240.0   93549.0      0.0
# 3   3775.0       0.0     134.0    2357.0      2.0   2825.0   36647.0      0.0
# 4   2794.0       0.0      82.0    1936.0      3.0    830.0   21890.0      0.0
#
#    WMCmaxT  WMCsumT  NCminT  NCmaxT  NCsumT  DITminT  DITmaxT  DITsumT  \
# 0    242.0  20170.0     0.0    10.0   335.0      0.0      5.0    407.0
# 1    844.0  19850.0     0.0     8.0   185.0      0.0      4.0    230.0
# 2    614.0  19677.0     0.0    11.0   339.0      0.0      3.0    398.0
# 3    661.0   7886.0     0.0     9.0    79.0      0.0      3.0    101.0
# 4    268.0   5268.0     0.0     8.0    57.0      0.0      2.0     67.0
#
#    LCOMminT  LCOMmaxT    LCOMsumT  FANINminT  FANINmaxT  FANINsumT  \
# 0      -1.0       1.0 -415.057283        0.0      251.0     7292.0
# 1      -1.0       1.0 -472.204330        0.0      427.0     3946.0
# 2      -1.0       1.0 -386.928680        0.0       94.0     3652.0
# 3      -1.0       1.0  -47.840461        0.0       30.0      962.0
# 4      -1.0       1.0  -24.434676        0.0       21.0      613.0
#
#    FANOUTminT  FANOUTmaxT  FANOUTsumT  typeCount        repository_name  \
# 0         0.0        46.0      7292.0     2048.0          alibaba/nacos
# 1         0.0        28.0      3946.0     1279.0           apache/dubbo
# 2         0.0        25.0      3652.0     1585.0  pinpoint-apm/pinpoint
# 3         0.0        36.0       962.0      384.0    TeamNewPipe/NewPipe
# 4         0.0        21.0       613.0      261.0    TeamNewPipe/NewPipe
#
#      release_x             info_x  LOCminM  LOCmaxM  LOCsumM  CCminM  CCmaxM  \
# 0        2.2.3        nacos-2.2.3      0.0    227.0  97801.0     1.0    45.0
# 1  dubbo-2.6.4  dubbo-dubbo-2.6.4      0.0    272.0  84466.0     1.0    66.0
# 2        1.1.2     pinpoint-1.1.2      0.0    227.0  79411.0     1.0    67.0
# 3      0.21.12    NewPipe-0.21.12      0.0    198.0  32419.0     1.0    45.0
# 4       0.13.4     NewPipe-0.13.4      0.0    104.0  19618.0     1.0    21.0
#
#     CCsumM  PCminM  PCmaxM   PCsumM  methodCount    release_y  \
# 0  20170.0     0.0    15.0  13392.0      12760.0        2.2.3
# 1  19850.0     0.0    12.0   9659.0       9010.0  dubbo-2.6.4
# 2  19677.0     0.0    15.0   9814.0       9196.0        1.1.2
# 3   7886.0     0.0    10.0   3850.0       3483.0      0.21.12
# 4   5268.0     0.0    11.0   2956.0       2590.0       0.13.4
#
#               info_y  Abstract Function Call From Constructor  \
# 0        nacos-2.2.3                                      1.0
# 1  dubbo-dubbo-2.6.4                                      2.0
# 2     pinpoint-1.1.2                                      0.0
# 3    NewPipe-0.21.12                                      0.0
# 4     NewPipe-0.13.4                                      0.0
#
#    Complex Conditional  Complex Method  Empty catch clause  Long Identifier  \
# 0                 63.0           105.0               139.0            226.0
# 1                165.0           217.0               235.0              5.0
# 2                 33.0           293.0                79.0            162.0
# 3                143.0           110.0                24.0             35.0
# 4                 84.0            61.0                12.0             13.0
#
#    Long Method  Long Parameter List  Long Statement  Magic Number  \
# 0          9.0                514.0          2520.0        2422.0
# 1         25.0                 71.0          1152.0        2203.0
# 2         34.0                175.0           814.0        2574.0
# 3          5.0                 41.0           733.0         947.0
# 4          1.0                 48.0           505.0         456.0
#
#    Missing default  Broken Hierarchy  Broken Modularization  Cyclic Hierarchy  \
# 0             48.0             103.0                   38.0               0.0
# 1            151.0              53.0                    1.0               0.0
# 2            102.0              86.0                    5.0               0.0
# 3             85.0              24.0                    6.0               0.0
# 4             54.0              12.0                    3.0               0.0
#
#    Cyclic-Dependent Modularization  Deep Hierarchy  Deficient Encapsulation  \
# 0                             99.0             0.0                    219.0
# 1                             35.0             0.0                    161.0
# 2                             32.0             0.0                    174.0
# 3                             86.0             0.0                    115.0
# 4                             51.0             0.0                     73.0
#
#    Hub-like Modularization  Imperative Abstraction  \
# 0                      1.0                     2.0
# 1                      0.0                    15.0
# 2                      0.0                     1.0
# 3                      1.0                     0.0
# 4                      0.0                     0.0
#
#    Insufficient Modularization  Missing Hierarchy  Multifaceted Abstraction  \
# 0                         88.0                3.0                       3.0
# 1                        127.0                2.0                       0.0
# 2                         69.0                2.0                       1.0
# 3                         32.0                2.0                       0.0
# 4                         25.0                1.0                       0.0
#
#    Multipath Hierarchy  Rebellious Hierarchy  Unexploited Encapsulation  \
# 0                  0.0                   0.0                        2.0
# 1                  1.0                   0.0                        0.0
# 2                  2.0                   0.0                        1.0
# 3                  0.0                   2.0                        0.0
# 4                  0.0                   2.0                        0.0
#
#    Unnecessary Abstraction  Unutilized Abstraction  Wide Hierarchy  \
# 0                     82.0                  1066.0             0.0
# 1                     53.0                   879.0             0.0
# 2                     36.0                   910.0             1.0
# 3                     19.0                   159.0             0.0
# 4                      1.0                   107.0             0.0
#
#       tag_name published_at_timestamp    tag_name2  duration_days  \
# 0        2.2.3    2023-05-25 07:40:58        2.2.3       0.019954
# 1  dubbo-2.6.4    2018-10-08 07:26:15  dubbo-2.6.4      45.809178
# 2        1.1.2    2015-11-24 09:10:58        1.1.2       1.813681
# 3     v0.21.12    2021-10-12 18:40:43      0.21.12       9.086262
# 4      v0.13.4    2018-05-25 16:42:28       0.13.4      10.109248
#
#    countOfIssue  avgResTime  issueDensity  totalDesignSmells  \
# 0           0.0         NaN      0.000000             1706.0
# 1          99.0   77.119970      2.161139             1327.0
# 2           5.0   14.895641      2.756825             1320.0
# 3          45.0   35.751292      4.952532              446.0
# 4          24.0  351.621116      2.374064              275.0
#
#    totalImplementationSmells
# 0                     6047.0
# 1                     4226.0
# 2                     4266.0
# 3                     2123.0
# 4                     1234.0

# %%
summary = summary.drop(columns=['release_y','info_y'])
summary.rename(columns={'release_x': 'release'}, inplace=True)
summary.rename(columns={'info_x': 'info'}, inplace=True)

# %%
summary.head()
# Out:
#    NOFminT  NOFmaxT  NOFsumT  NOPFminT  NOPFmaxT  NOPFsumT  NOMminT  NOMmaxT  \
# 0      0.0     92.0   6724.0       0.0      92.0    1175.0      0.0    110.0
# 1      0.0    267.0   3894.0       0.0     267.0     751.0      0.0    515.0
# 2      0.0    109.0   4282.0       0.0      52.0     456.0      0.0    144.0
# 3      0.0    108.0   2111.0       0.0      37.0     407.0      0.0    245.0
# 4      0.0     54.0   1364.0       0.0      17.0     300.0      0.0     94.0
#
#    NOMsumT  NOPMminT  NOPMmaxT  NOPMsumT  LOCminT  LOCmaxT   LOCsumT  WMCminT  \
# 0  13998.0       0.0     108.0   11633.0      2.0   1862.0  133961.0      0.0
# 1  11824.0       0.0     457.0    9904.0      2.0   3827.0  100175.0      0.0
# 2  10302.0       0.0     141.0    8014.0      2.0   2240.0   93549.0      0.0
# 3   3775.0       0.0     134.0    2357.0      2.0   2825.0   36647.0      0.0
# 4   2794.0       0.0      82.0    1936.0      3.0    830.0   21890.0      0.0
#
#    WMCmaxT  WMCsumT  NCminT  NCmaxT  NCsumT  DITminT  DITmaxT  DITsumT  \
# 0    242.0  20170.0     0.0    10.0   335.0      0.0      5.0    407.0
# 1    844.0  19850.0     0.0     8.0   185.0      0.0      4.0    230.0
# 2    614.0  19677.0     0.0    11.0   339.0      0.0      3.0    398.0
# 3    661.0   7886.0     0.0     9.0    79.0      0.0      3.0    101.0
# 4    268.0   5268.0     0.0     8.0    57.0      0.0      2.0     67.0
#
#    LCOMminT  LCOMmaxT    LCOMsumT  FANINminT  FANINmaxT  FANINsumT  \
# 0      -1.0       1.0 -415.057283        0.0      251.0     7292.0
# 1      -1.0       1.0 -472.204330        0.0      427.0     3946.0
# 2      -1.0       1.0 -386.928680        0.0       94.0     3652.0
# 3      -1.0       1.0  -47.840461        0.0       30.0      962.0
# 4      -1.0       1.0  -24.434676        0.0       21.0      613.0
#
#    FANOUTminT  FANOUTmaxT  FANOUTsumT  typeCount        repository_name  \
# 0         0.0        46.0      7292.0     2048.0          alibaba/nacos
# 1         0.0        28.0      3946.0     1279.0           apache/dubbo
# 2         0.0        25.0      3652.0     1585.0  pinpoint-apm/pinpoint
# 3         0.0        36.0       962.0      384.0    TeamNewPipe/NewPipe
# 4         0.0        21.0       613.0      261.0    TeamNewPipe/NewPipe
#
#        release               info  LOCminM  LOCmaxM  LOCsumM  CCminM  CCmaxM  \
# 0        2.2.3        nacos-2.2.3      0.0    227.0  97801.0     1.0    45.0
# 1  dubbo-2.6.4  dubbo-dubbo-2.6.4      0.0    272.0  84466.0     1.0    66.0
# 2        1.1.2     pinpoint-1.1.2      0.0    227.0  79411.0     1.0    67.0
# 3      0.21.12    NewPipe-0.21.12      0.0    198.0  32419.0     1.0    45.0
# 4       0.13.4     NewPipe-0.13.4      0.0    104.0  19618.0     1.0    21.0
#
#     CCsumM  PCminM  PCmaxM   PCsumM  methodCount  \
# 0  20170.0     0.0    15.0  13392.0      12760.0
# 1  19850.0     0.0    12.0   9659.0       9010.0
# 2  19677.0     0.0    15.0   9814.0       9196.0
# 3   7886.0     0.0    10.0   3850.0       3483.0
# 4   5268.0     0.0    11.0   2956.0       2590.0
#
#    Abstract Function Call From Constructor  Complex Conditional  \
# 0                                      1.0                 63.0
# 1                                      2.0                165.0
# 2                                      0.0                 33.0
# 3                                      0.0                143.0
# 4                                      0.0                 84.0
#
#    Complex Method  Empty catch clause  Long Identifier  Long Method  \
# 0           105.0               139.0            226.0          9.0
# 1           217.0               235.0              5.0         25.0
# 2           293.0                79.0            162.0         34.0
# 3           110.0                24.0             35.0          5.0
# 4            61.0                12.0             13.0          1.0
#
#    Long Parameter List  Long Statement  Magic Number  Missing default  \
# 0                514.0          2520.0        2422.0             48.0
# 1                 71.0          1152.0        2203.0            151.0
# 2                175.0           814.0        2574.0            102.0
# 3                 41.0           733.0         947.0             85.0
# 4                 48.0           505.0         456.0             54.0
#
#    Broken Hierarchy  Broken Modularization  Cyclic Hierarchy  \
# 0             103.0                   38.0               0.0
# 1              53.0                    1.0               0.0
# 2              86.0                    5.0               0.0
# 3              24.0                    6.0               0.0
# 4              12.0                    3.0               0.0
#
#    Cyclic-Dependent Modularization  Deep Hierarchy  Deficient Encapsulation  \
# 0                             99.0             0.0                    219.0
# 1                             35.0             0.0                    161.0
# 2                             32.0             0.0                    174.0
# 3                             86.0             0.0                    115.0
# 4                             51.0             0.0                     73.0
#
#    Hub-like Modularization  Imperative Abstraction  \
# 0                      1.0                     2.0
# 1                      0.0                    15.0
# 2                      0.0                     1.0
# 3                      1.0                     0.0
# 4                      0.0                     0.0
#
#    Insufficient Modularization  Missing Hierarchy  Multifaceted Abstraction  \
# 0                         88.0                3.0                       3.0
# 1                        127.0                2.0                       0.0
# 2                         69.0                2.0                       1.0
# 3                         32.0                2.0                       0.0
# 4                         25.0                1.0                       0.0
#
#    Multipath Hierarchy  Rebellious Hierarchy  Unexploited Encapsulation  \
# 0                  0.0                   0.0                        2.0
# 1                  1.0                   0.0                        0.0
# 2                  2.0                   0.0                        1.0
# 3                  0.0                   2.0                        0.0
# 4                  0.0                   2.0                        0.0
#
#    Unnecessary Abstraction  Unutilized Abstraction  Wide Hierarchy  \
# 0                     82.0                  1066.0             0.0
# 1                     53.0                   879.0             0.0
# 2                     36.0                   910.0             1.0
# 3                     19.0                   159.0             0.0
# 4                      1.0                   107.0             0.0
#
#       tag_name published_at_timestamp    tag_name2  duration_days  \
# 0        2.2.3    2023-05-25 07:40:58        2.2.3       0.019954
# 1  dubbo-2.6.4    2018-10-08 07:26:15  dubbo-2.6.4      45.809178
# 2        1.1.2    2015-11-24 09:10:58        1.1.2       1.813681
# 3     v0.21.12    2021-10-12 18:40:43      0.21.12       9.086262
# 4      v0.13.4    2018-05-25 16:42:28       0.13.4      10.109248
#
#    countOfIssue  avgResTime  issueDensity  totalDesignSmells  \
# 0           0.0         NaN      0.000000             1706.0
# 1          99.0   77.119970      2.161139             1327.0
# 2           5.0   14.895641      2.756825             1320.0
# 3          45.0   35.751292      4.952532              446.0
# 4          24.0  351.621116      2.374064              275.0
#
#    totalImplementationSmells
# 0                     6047.0
# 1                     4226.0
# 2                     4266.0
# 3                     2123.0
# 4                     1234.0

# %%
#summary.to_csv('summary.csv', index=False)
#summary2 = pd.read_csv('summary.csv')

# %%
r = summary['repository_name'].unique()

i = 0 
while i < len(r):
    repository = r[i]
    summaryR = summary[summary['repository_name'] == repository]
    summaryR['published_at_timestamp'] = pd.to_datetime(summaryR['published_at_timestamp'])
    summaryR = summaryR.sort_values(by='published_at_timestamp')
    plt.figure(figsize=(20, 8))
    plt.scatter(summaryR['published_at_timestamp'], summaryR['totalDesignSmells'], marker='o', color='cornflowerblue', label='totalDesignSmells')
    plt.scatter(summaryR['published_at_timestamp'], summaryR['totalImplementationSmells'], marker='o', color='darkorange', label='totalImplementationSmells')
    plt.scatter(summaryR['published_at_timestamp'], summaryR['countOfIssue'], marker='o', color='yellow', label='countOfIssue')
    plt.scatter(summaryR['published_at_timestamp'], summaryR['issueDensity'], marker='o', color='red', label='issueDensity')
    plt.scatter(summaryR['published_at_timestamp'], summaryR['avgResTime'], marker='o', color='limegreen', label='avgResTime')
    plt.title(f'{repository},{summaryR.shape[0]}')
    plt.xlabel('Timestamp')
    plt.ylabel('number of occurrence')
    plt.grid(True)
    plt.legend()
    plt.show()
    i = i + 1

# %%
r
# Out:
# array(['alibaba/nacos', 'apache/dubbo', 'pinpoint-apm/pinpoint',
#        'TeamNewPipe/NewPipe', 'OpenAPITools/openapi-generator',
#        'facebook/react-native', 'Anuken/Mindustry', 'mockito/mockito',
#        'Netflix/conductor', 'spring-projects/spring-framework',
#        'zaproxy/zaproxy', 'spring-projects/spring-boot', 'neo4j/neo4j',
#        'grpc/grpc-java', 'questdb/questdb', 'elastic/logstash',
#        'quarkusio/quarkus', 'dbeaver/dbeaver', 'elastic/elasticsearch',
#        'apache/shardingsphere', 'ReactiveX/RxJava', 'apache/pulsar',
#        'SeleniumHQ/selenium', 'GoogleContainerTools/jib',
#        'bazelbuild/bazel', 'apache/druid', 'openzipkin/zipkin',
#        'redis/jedis', 'apache/skywalking',
#        'codecentric/spring-boot-admin', 'halo-dev/halo',
#        'thingsboard/thingsboard'], dtype=object)

# %%
repository = r[9]

summaryR = summary[summary['repository_name'] == repository]
summaryR['published_at_timestamp'] = pd.to_datetime(summaryR['published_at_timestamp'])
summaryR = summaryR.sort_values(by='published_at_timestamp')
plt.figure(figsize=(20, 8))
plt.scatter(summaryR['published_at_timestamp'], summaryR['totalDesignSmells'], marker='o', color='cornflowerblue', label='totalDesignSmells')
plt.scatter(summaryR['published_at_timestamp'], summaryR['totalImplementationSmells'], marker='o', color='darkorange', label='totalImplementationSmells')
#plt.scatter(summaryR['published_at_timestamp'], summaryR['countOfIssue'], marker='o', color='yellow', label='countOfIssue')
#plt.scatter(summaryR['published_at_timestamp'], summaryR['issueDensity'], marker='o', color='red', label='issueDensity')
#plt.scatter(summaryR['published_at_timestamp'], summaryR['avgResTime'], marker='o', color='limegreen', label='avgResTime')
issuesR = issues[issues['repository_name'] == repository]
issuesR['created_at_timestamp'] = pd.to_datetime(issuesR['created_at_timestamp'])
issuesR = issuesR.sort_values(by='created_at_timestamp')
issuesRCount = issuesR.groupby(['created_at_timestamp'])['url'].count().reset_index(name="countOfIssue")
plt.scatter(issuesRCount['created_at_timestamp'], issuesRCount['countOfIssue'], marker='o', color='limegreen', label='countOfIssue')
plt.title(f'{repository},{summaryR.shape[0]}')
plt.xlabel('Timestamp')
plt.ylabel('number of occurrence')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ### Making corrections in release published dates

# %%
releasesC = releases.copy(deep=True)

# %% [markdown]
# spring-projects/spring-framework

# %%
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v3.0.0.M1')].index,'published_at_timestamp'] = pd.Timestamp('2008-12-19 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v3.0.0.M2')].index,'published_at_timestamp'] = pd.Timestamp('2009-02-25 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v3.0.0.M3')].index,'published_at_timestamp'] = pd.Timestamp('2009-05-06 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v3.0.0.M4')].index,'published_at_timestamp'] = pd.Timestamp('2009-08-10 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v3.0.0.RC1')].index,'published_at_timestamp'] = pd.Timestamp('2009-09-28 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v3.0.0.RC2')].index,'published_at_timestamp'] = pd.Timestamp('2009-11-13 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v3.0.0.RC3')].index,'published_at_timestamp'] = pd.Timestamp('2009-12-01 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v3.0.0.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2009-12-16 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v3.0.1.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2010-02-18 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v3.0.2.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2010-04-02 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v3.0.3.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2010-06-15 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v3.0.4.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2010-08-19 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v3.0.5.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2010-10-21 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v3.1.0.M1')].index,'published_at_timestamp'] = pd.Timestamp('2011-02-11 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v3.1.0.M2')].index,'published_at_timestamp'] = pd.Timestamp('2011-06-08 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v3.0.6.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2011-08-19 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v3.1.0.RC1')].index,'published_at_timestamp'] = pd.Timestamp('2011-10-12 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v3.1.0.RC2')].index,'published_at_timestamp'] = pd.Timestamp('2011-11-29 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v3.1.0.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2011-12-13 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v3.0.7.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2011-12-22 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v3.1.1.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2012-02-17 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v3.2.0.M1')].index,'published_at_timestamp'] = pd.Timestamp('2012-05-28 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v3.1.2.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2012-07-07 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v3.2.0.M2')].index,'published_at_timestamp'] = pd.Timestamp('2012-09-12 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v3.1.3.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2012-10-31 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v3.2.0.RC1')].index,'published_at_timestamp'] = pd.Timestamp('2012-11-04 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v3.2.0.RC2')].index,'published_at_timestamp'] = pd.Timestamp('2012-11-27 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v3.2.0.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2012-12-13 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v3.1.4.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2013-01-23 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v3.2.1.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2013-01-24 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v3.2.2.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2013-03-13 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v4.0.0.M1')].index,'published_at_timestamp'] = pd.Timestamp('2013-05-17 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v3.2.3.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2013-05-20 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v4.0.0.M2')].index,'published_at_timestamp'] = pd.Timestamp('2013-07-24 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v3.2.4.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2013-08-07 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v4.0.0.M3')].index,'published_at_timestamp'] = pd.Timestamp('2013-08-30 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v4.0.0.RC1')].index,'published_at_timestamp'] = pd.Timestamp('2013-10-31 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v3.2.5.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2013-11-06 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v4.0.0.RC2')].index,'published_at_timestamp'] = pd.Timestamp('2013-12-04 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v3.2.6.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2013-12-12 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v4.0.0.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2013-12-12 12:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v3.2.7.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2014-01-29 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v4.0.1.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2014-01-28 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v3.2.8.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2014-02-19 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v4.0.2.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2014-02-19 12:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v4.0.3.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2014-03-27 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v4.0.4.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2014-05-01 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v3.2.9.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2014-05-20 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v4.0.5.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2014-05-20 12:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v4.0.6.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2014-07-08 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v3.2.10.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2014-07-16 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v4.1.0.RC1')].index,'published_at_timestamp'] = pd.Timestamp('2014-07-18 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v4.1.0.RC2')].index,'published_at_timestamp'] = pd.Timestamp('2014-08-15 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v3.2.11.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2014-09-04 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v4.0.7.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2014-09-04 08:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v4.1.0.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2014-09-04 16:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v4.1.1.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2014-10-01 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v3.2.12.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2014-11-11 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v4.0.8.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2014-11-11 08:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v4.1.2.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2014-11-11 16:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v4.1.3.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2014-12-09 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v3.2.13.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2014-12-30 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v4.0.9.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2014-12-30 08:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v4.1.4.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2014-12-30 16:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v4.1.5.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2015-02-20 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v4.1.6.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2015-03-25 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v4.2.0.RC1')].index,'published_at_timestamp'] = pd.Timestamp('2015-05-26 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v3.2.14.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2015-06-30 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v4.1.7.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2015-06-30 12:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v4.2.0.RC2')].index,'published_at_timestamp'] = pd.Timestamp('2015-07-01 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v4.2.0.RC3')].index,'published_at_timestamp'] = pd.Timestamp('2015-07-15 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v4.2.0.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2015-07-31 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v4.2.1.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2015-09-01 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v3.2.15.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2015-10-15 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v4.1.8.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2015-10-15 08:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v4.2.2.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2015-10-15 16:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v4.2.3.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2015-11-15 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v3.2.16.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2015-12-17 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v4.1.9.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2015-12-17 08:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v4.2.4.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2015-12-17 16:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v4.2.5.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2016-02-25 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v4.3.0.RC1')].index,'published_at_timestamp'] = pd.Timestamp('2016-04-06 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v3.2.17.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2016-05-06 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v4.2.6.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2016-05-06 08:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v4.3.0.RC2')].index,'published_at_timestamp'] = pd.Timestamp('2016-05-06 16:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v4.3.0.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2016-06-10 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v4.2.7.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2016-07-04 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v4.3.1.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2016-07-04 12:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v4.3.2.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2016-07-28 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v5.0.0.M1')].index,'published_at_timestamp'] = pd.Timestamp('2016-07-28 12:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v4.2.8.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2016-09-19 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v4.3.3.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2016-09-19 12:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v5.0.0.M2')].index,'published_at_timestamp'] = pd.Timestamp('2016-09-21 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v4.3.4.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2016-11-08 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v5.0.0.M3')].index,'published_at_timestamp'] = pd.Timestamp('2016-11-08 12:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v3.2.18.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2016-12-21 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v4.2.9.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2016-12-21 08:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v4.3.5.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2016-12-21 16:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v5.0.0.M4')].index,'published_at_timestamp'] = pd.Timestamp('2016-12-30 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v4.3.6.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2017-01-25 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v5.0.0.M5')].index,'published_at_timestamp'] = pd.Timestamp('2017-02-23 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v4.3.7.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2017-03-01 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v4.3.8.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2017-04-18 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v5.0.0.RC1')].index,'published_at_timestamp'] = pd.Timestamp('2017-05-08 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v4.3.9.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2017-06-07 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v5.0.0.RC2')].index,'published_at_timestamp'] = pd.Timestamp('2017-06-14 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v4.3.10.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2017-07-20 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v5.0.0.RC3')].index,'published_at_timestamp'] = pd.Timestamp('2017-07-24 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v4.3.11.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2017-09-11 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v5.0.0.RC4')].index,'published_at_timestamp'] = pd.Timestamp('2017-09-11 12:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v5.0.0.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2017-09-28 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v4.3.12.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2017-10-10 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v5.0.1.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2017-10-24 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v4.3.13.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2017-11-27 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v5.0.2.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2017-11-27 12:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v4.3.14.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2018-01-23 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v5.0.3.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2018-01-23 12:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v5.0.4.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2018-02-19 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v4.3.15.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2018-04-03 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v5.0.5.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2018-04-03 12:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v4.3.16.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2018-04-09 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v4.3.17.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2018-05-08 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v5.0.6.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2018-05-08 12:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v4.3.18.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2018-06-12 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v5.0.7.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2018-06-12 12:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v5.0.8.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2018-07-26 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v5.1.0.RC1')].index,'published_at_timestamp'] = pd.Timestamp('2018-07-26 12:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v5.1.0.RC2')].index,'published_at_timestamp'] = pd.Timestamp('2018-08-17 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v4.3.19.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2018-09-07 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v5.0.9.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2018-09-07 08:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v5.1.0.RC3')].index,'published_at_timestamp'] = pd.Timestamp('2018-09-07 16:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v5.1.0.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2018-09-21 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v4.3.20.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2018-10-15 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v5.0.10.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2018-10-15 08:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v5.1.1.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2018-10-15 16:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v5.1.2.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2018-10-29 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v4.3.21.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2018-11-27 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v5.0.11.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2018-11-27 08:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v5.1.3.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2018-11-27 16:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v4.3.22.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2019-01-09 00:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v5.0.12.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2019-01-09 08:00:00')
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v5.1.4.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2019-01-09 16:00:00')

# %%
# spring-projects/spring-framework is correct starting with the below release
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'v5.1.5.RELEASE')].index,'published_at_timestamp'] = pd.Timestamp('2019-02-13 00:00:00')

# %% [markdown]
# spring-projects/spring-boot

# %%
releasesC.loc[releasesC[(releasesC['repository_name'] == r[9]) & (releasesC['tag_name'] == 'x')].index,'published_at_timestamp'] = pd.Timestamp('xxxx-xx-xx 00:00:00')

# %%
repository = r[11]

summaryR = summary[summary['repository_name'] == repository]
summaryR['published_at_timestamp'] = pd.to_datetime(summaryR['published_at_timestamp'])
summaryR = summaryR.sort_values(by='published_at_timestamp')
plt.figure(figsize=(20, 8))
plt.scatter(summaryR['published_at_timestamp'], summaryR['totalDesignSmells'], marker='o', color='cornflowerblue', label='totalDesignSmells')
plt.scatter(summaryR['published_at_timestamp'], summaryR['totalImplementationSmells'], marker='o', color='darkorange', label='totalImplementationSmells')
#plt.scatter(summaryR['published_at_timestamp'], summaryR['countOfIssue'], marker='o', color='yellow', label='countOfIssue')
#plt.scatter(summaryR['published_at_timestamp'], summaryR['issueDensity'], marker='o', color='red', label='issueDensity')
#plt.scatter(summaryR['published_at_timestamp'], summaryR['avgResTime'], marker='o', color='limegreen', label='avgResTime')
issuesR = issues[issues['repository_name'] == repository]
issuesR['created_at_timestamp'] = pd.to_datetime(issuesR['created_at_timestamp'])
issuesR = issuesR.sort_values(by='created_at_timestamp')
issuesRCount = issuesR.groupby(['created_at_timestamp'])['url'].count().reset_index(name="countOfIssue")
plt.scatter(issuesRCount['created_at_timestamp'], issuesRCount['countOfIssue'], marker='o', color='limegreen', label='countOfIssue')
plt.title(f'{repository},{summaryR.shape[0]}')
plt.xlabel('Timestamp')
plt.ylabel('number of occurrence')
plt.grid(True)
plt.legend()
plt.show()

# %%
repository = r[11]

summaryR = summary[summary['repository_name'] == repository]
summaryR['published_at_timestamp'] = pd.to_datetime(summaryR['published_at_timestamp'])
summaryR = summaryR.sort_values(by='published_at_timestamp')
plt.figure(figsize=(20, 8))
#plt.scatter(summaryR['published_at_timestamp'], summaryR['totalDesignSmells'], marker='o', color='cornflowerblue', label='totalDesignSmells')
#plt.scatter(summaryR['published_at_timestamp'], summaryR['totalImplementationSmells'], marker='o', color='darkorange', label='totalImplementationSmells')
#plt.scatter(summaryR['published_at_timestamp'], summaryR['countOfIssue'], marker='o', color='yellow', label='countOfIssue')
#plt.scatter(summaryR['published_at_timestamp'], summaryR['issueDensity'], marker='o', color='red', label='issueDensity')
#plt.scatter(summaryR['published_at_timestamp'], summaryR['avgResTime'], marker='o', color='limegreen', label='avgResTime')
issuesR = issues[issues['repository_name'] == repository]
issuesR['created_at_timestamp'] = pd.to_datetime(issuesR['created_at_timestamp'])
issuesR = issuesR.sort_values(by='created_at_timestamp')
issuesRCount = issuesR.groupby(['created_at_timestamp'])['url'].count().reset_index(name="countOfIssue")
plt.scatter(issuesRCount['created_at_timestamp'], issuesRCount['countOfIssue'], marker='o', color='limegreen', label='countOfIssue')
plt.title(f'{repository},{summaryR.shape[0]}')
plt.xlabel('Timestamp')
plt.ylabel('number of occurrence')
plt.grid(True)
plt.legend()
plt.show()

# %%
i = 0
while i < len(r):
    repository = r[i]
    summaryR = summary[summary['repository_name'] == repository]
    summaryR['published_at_timestamp'] = pd.to_datetime(summaryR['published_at_timestamp'])
    summaryR = summaryR.sort_values(by='published_at_timestamp')
    plt.figure(figsize=(20, 8))
    plt.scatter(summaryR['published_at_timestamp'], summaryR['totalDesignSmells'], marker='o', color='cornflowerblue', label='totalDesignSmells')
    plt.scatter(summaryR['published_at_timestamp'], summaryR['totalImplementationSmells'], marker='o', color='darkorange', label='totalImplementationSmells')
    #plt.scatter(summaryR['published_at_timestamp'], summaryR['countOfIssue'], marker='o', color='yellow', label='countOfIssue')
    #plt.scatter(summaryR['published_at_timestamp'], summaryR['issueDensity'], marker='o', color='red', label='issueDensity')
    #plt.scatter(summaryR['published_at_timestamp'], summaryR['avgResTime'], marker='o', color='limegreen', label='avgResTime')
    issuesR = issues[issues['repository_name'] == repository]
    issuesR['created_at_timestamp'] = pd.to_datetime(issuesR['created_at_timestamp'])
    issuesR = issuesR.sort_values(by='created_at_timestamp')
    issuesRCount = issuesR.groupby(['created_at_timestamp'])['url'].count().reset_index(name="countOfIssue")
    plt.scatter(issuesRCount['created_at_timestamp'], issuesRCount['countOfIssue'], marker='o', color='limegreen', label='countOfIssue')
    plt.title(f'{repository},{summaryR.shape[0]}')
    plt.xlabel('Timestamp')
    plt.ylabel('number of occurrence')
    plt.grid(True)
    plt.legend()
    plt.show()
    i = i + 1

# %%
repository = r[0]

summaryR = summary[summary['repository_name'] == repository]
summaryR['published_at_timestamp'] = pd.to_datetime(summaryR['published_at_timestamp'])
summaryR = summaryR.sort_values(by='published_at_timestamp')
plt.figure(figsize=(20, 8))
#plt.scatter(summaryR['published_at_timestamp'], summaryR['totalDesignSmells'], marker='o', color='cornflowerblue', label='totalDesignSmells')
#plt.scatter(summaryR['published_at_timestamp'], summaryR['totalImplementationSmells'], marker='o', color='darkorange', label='totalImplementationSmells')
#plt.scatter(summaryR['published_at_timestamp'], summaryR['countOfIssue'], marker='o', color='yellow', label='countOfIssue')
#plt.scatter(summaryR['published_at_timestamp'], summaryR['issueDensity'], marker='o', color='red', label='issueDensity')
#plt.scatter(summaryR['published_at_timestamp'], summaryR['avgResTime'], marker='o', color='limegreen', label='avgResTime')
issuesR = issues[issues['repository_name'] == repository]
issuesR['created_at_timestamp'] = pd.to_datetime(issuesR['created_at_timestamp'])
issuesR = issuesR.sort_values(by='created_at_timestamp')
issuesRCount = issuesR.groupby(['created_at_timestamp'])['url'].count().reset_index(name="countOfIssue")
plt.scatter(issuesRCount['created_at_timestamp'], issuesRCount['countOfIssue'], marker='o', color='limegreen', label='countOfIssue')
plt.title(f'{repository},{summaryR.shape[0]}')
plt.xlabel('Timestamp')
plt.ylabel('number of occurrence')
plt.grid(True)
plt.legend()
plt.show()
